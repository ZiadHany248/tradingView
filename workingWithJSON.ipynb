# %% [markdown]
# ## This section is defining functions for pulling country links and also compiling parameters

# %%
import json
import re
import os
import requests
from bs4 import BeautifulSoup
import http.client
import csv
import time
from datetime import datetime

# %%
basePath = 'E:\\webscr\\tradingView\\'

# %%
def compileAllParameters(payloadsPath):
    
    """
    Description: This function compiles a list of all parameters used across most tables on the website
    TradingView by accessing them from pre-downloaded and stored payload files in json form
    
    payloadsPath: The path to the payloads 
    paramList: A list of all the parameters that were used in the files found in the provided path
    
    """
    
    paramList = []
    for payload in os.listdir(payloadsPath):

        if '.json' in payload:
            
            f = open(payloadsPath+payload, "r")
            myFile = f.read()
            myPayLoad=json.loads(myFile)
            for el in myPayLoad['columns']:
                paramList.append(el)
                f.close()

    paramList = list(set(paramList))
    return paramList

# %%
#This doesn't work actually!
def doubleQuotes(filePath):
    
    comp = open(filePath)
    myComp = comp.read()
    comp.close()
    myComp.replace("\'", "\"")
    
    return myComp

# %%
def extractCatName(country,payloadName):

    """
    Description: Grabs the names of the tables from a fileName.
    country: a string of the name of the country in question
    
    """
    myString = payloadName
    matchAgainst = '{}(.+?)Payload*'.format(country)
    n = re.search(matchAgainst,myString)
    #print(n.group(1))
    return n.group(1)

# %%
def countryLinksFromStr(containingString):

    """
    Description: This function takes a script that contains markets links and extracts those links
    and edits them to fit them into proper link form
    
    containingString: A string of an HTML script element 
    
    Returns: a list of links for all markets on TradingView
    """
    markets = list(set(re.findall('"url":"/markets/[world-]{0,10}stocks[-/][a-zA-Z-]{0,50}/?',containingString)))
    
    modMarkets = []
    for market in markets:
        modMarkets.append(['https://www.tradingview.com'+market[7:]+'market-movers-large-cap/',market[23:-1]])
    
    print(len(markets))
    
    return(modMarkets)

# %%
def countryLinksFromPage(pageLink):
    
    """
    Description:This function extracts the script which contains links to markets and passes it to another which
    extracts the links themselves
    
    pageLink: a link of the page from which we'd like to extract market links 
    
    Returns: A list of links of stock markets pages
    """
    
    page = requests.get(pageLink).text
    parsed = BeautifulSoup(page,'lxml')
    
    #Links are all stored in a script so they can be added and removed when the user hovers over the markets tab
    input_tag = parsed.findAll('script', attrs= {"type" : "application/prs.init-data+json"})
    
    
    for tag in input_tag:
        #only the script that contains the links has the word egypt in it. Could change
        if 'egypt' in str(tag):
            linksString = str(tag)
            
            
    return countryLinksFromStr(linksString)

# %%
 countryLinksFromPage('https://www.tradingview.com/markets/stocks-usa/market-movers-large-cap/')
# Out:
# 68
# [['https://www.tradingview.com/markets/stocks-switzerland/market-movers-large-cap/',
#   'switzerland'],
#  ['https://www.tradingview.com/markets/stocks-argentina/market-movers-large-cap/',
#   'argentina'],
#  ['https://www.tradingview.com/markets/stocks-canada/market-movers-large-cap/',
#   'canada'],
#  ['https://www.tradingview.com/markets/stocks-latvia/market-movers-large-cap/',
#   'latvia'],
#  ['https://www.tradingview.com/markets/stocks-belgium/market-movers-large-cap/',
#   'belgium'],
#  ['https://www.tradingview.com/markets/stocks-ksa/market-movers-large-cap/',
#   'ksa'],
#  ['https://www.tradingview.com/markets/stocks-netherlands/market-movers-large-cap/',
#   'netherlands'],
#  ['https://www.tradingview.com/markets/stocks-vietnam/market-movers-large-cap/',
#   'vietnam'],
#  ['https://www.tradingview.com/markets/stocks-venezuela/market-movers-large-cap/',
#   'venezuela'],
#  ['https://www.tradingview.com/markets/stocks-romania/market-movers-large-cap/',
#   'romania'],
#  ['https://www.tradingview.com/markets/stocks-japan/market-movers-large-cap/',
#   'japan'],
#  ['https://www.tradingview.com/markets/stocks-greece/market-movers-large-cap/',
#   'greece'],
#  ['https://www.tradingview.com/markets/stocks-pakistan/market-movers-large-cap/',
#   'pakistan'],
#  ['https://www.tradingview.com/markets/stocks-norway/market-movers-large-cap/',
#   'norway'],
#  ['https://www.tradingview.com/markets/stocks-singapore/market-movers-large-cap/',
#   'singapore'],
#  ['https://www.tradingview.com/markets/stocks-turkey/market-movers-large-cap/',
#   'turkey'],
#  ['https://www.tradingview.com/markets/stocks-sri-lanka/market-movers-large-cap/',
#   'sri-lanka'],
#  ['https://www.tradingview.com/markets/stocks-iceland/market-movers-large-cap/',
#   'iceland'],
#  ['https://www.tradingview.com/markets/stocks-spain/market-movers-large-cap/',
#   'spain'],
#  ['https://www.tradingview.com/markets/stocks-hong-kong/market-movers-large-cap/',
#   'hong-kong'],
#  ['https://www.tradingview.com/markets/stocks-serbia/market-movers-large-cap/',
#   'serbia'],
#  ['https://www.tradingview.com/markets/stocks-cyprus/market-movers-large-cap/',
#   'cyprus'],
#  ['https://www.tradingview.com/markets/stocks-bahrain/market-movers-large-cap/',
#   'bahrain'],
#  ['https://www.tradingview.com/markets/stocks-luxembourg/market-movers-large-cap/',
#   'luxembourg'],
#  ['https://www.tradingview.com/markets/stocks-new-zealand/market-movers-large-cap/',
#   'new-zealand'],
#  ['https://www.tradingview.com/markets/stocks-slovakia/market-movers-large-cap/',
#   'slovakia'],
#  ['https://www.tradingview.com/markets/stocks-colombia/market-movers-large-cap/',
#   'colombia'],
#  ['https://www.tradingview.com/markets/stocks-taiwan/market-movers-large-cap/',
#   'taiwan'],
#  ['https://www.tradingview.com/markets/stocks-kenya/market-movers-large-cap/',
#   'kenya'],
#  ['https://www.tradingview.com/markets/stocks-indonesia/market-movers-large-cap/',
#   'indonesia'],
#  ['https://www.tradingview.com/markets/stocks-qatar/market-movers-large-cap/',
#   'qatar'],
#  ['https://www.tradingview.com/markets/stocks-australia/market-movers-large-cap/',
#   'australia'],
#  ['https://www.tradingview.com/markets/stocks-sweden/market-movers-large-cap/',
#   'sweden'],
#  ['https://www.tradingview.com/markets/world-stocks/market-movers-large-cap/',
#   'tocks'],
#  ['https://www.tradingview.com/markets/stocks-france/market-movers-large-cap/',
#   'france'],
#  ['https://www.tradingview.com/markets/stocks-usa/market-movers-large-cap/',
#   'usa'],
#  ['https://www.tradingview.com/markets/stocks-mexico/market-movers-large-cap/',
#   'mexico'],
#  ['https://www.tradingview.com/markets/stocks-nigeria/market-movers-large-cap/',
#   'nigeria'],
#  ['https://www.tradingview.com/markets/stocks-peru/market-movers-large-cap/',
#   'peru'],
#  ['https://www.tradingview.com/markets/stocks-israel/market-movers-large-cap/',
#   'israel'],
#  ['https://www.tradingview.com/markets/stocks-korea/market-movers-large-cap/',
#   'korea'],
#  ['https://www.tradingview.com/markets/stocks-hungary/market-movers-large-cap/',
#   'hungary'],
#  ['https://www.tradingview.com/markets/stocks-united-kingdom/market-movers-large-cap/',
#   'united-kingdom'],
#  ['https://www.tradingview.com/markets/stocks-denmark/market-movers-large-cap/',
#   'denmark'],
#  ['https://www.tradingview.com/markets/stocks-south-africa/market-movers-large-cap/',
#   'south-africa'],
#  ['https://www.tradingview.com/markets/stocks-philippines/market-movers-large-cap/',
#   'philippines'],
#  ['https://www.tradingview.com/markets/stocks-malaysia/market-movers-large-cap/',
#   'malaysia'],
#  ['https://www.tradingview.com/markets/stocks-germany/market-movers-large-cap/',
#   'germany'],
#  ['https://www.tradingview.com/markets/stocks-estonia/market-movers-large-cap/',
#   'estonia'],
#  ['https://www.tradingview.com/markets/stocks-brazil/market-movers-large-cap/',
#   'brazil'],
#  ['https://www.tradingview.com/markets/stocks-lithuania/market-movers-large-cap/',
#   'lithuania'],
#  ['https://www.tradingview.com/markets/stocks-austria/market-movers-large-cap/',
#   'austria'],
#  ['https://www.tradingview.com/markets/stocks-india/market-movers-large-cap/',
#   'india'],
#  ['https://www.tradingview.com/markets/stocks-china/market-movers-large-cap/',
#   'china'],
#  ['https://www.tradingview.com/markets/stocks-czech/market-movers-large-cap/',
#   'czech'],
#  ['https://www.tradingview.com/markets/stocks-finland/market-movers-large-cap/',
#   'finland'],
#  ['https://www.tradingview.com/markets/stocks-kuwait/market-movers-large-cap/',
#   'kuwait'],
#  ['https://www.tradingview.com/markets/stocks-russia/market-movers-large-cap/',
#   'russia'],
#  ['https://www.tradingview.com/markets/stocks-tunisia/market-movers-large-cap/',
#   'tunisia'],
#  ['https://www.tradingview.com/markets/stocks-uae/market-movers-large-cap/',
#   'uae'],
#  ['https://www.tradingview.com/markets/stocks-poland/market-movers-large-cap/',
#   'poland'],
#  ['https://www.tradingview.com/markets/stocks-portugal/market-movers-large-cap/',
#   'portugal'],
#  ['https://www.tradingview.com/markets/stocks-egypt/market-movers-large-cap/',
#   'egypt'],
#  ['https://www.tradingview.com/markets/stocks-italy/market-movers-large-cap/',
#   'italy'],
#  ['https://www.tradingview.com/markets/stocks-chile/market-movers-large-cap/',
#   'chile'],
#  ['https://www.tradingview.com/markets/stocks-morocco/market-movers-large-cap/',
#   'morocco'],
#  ['https://www.tradingview.com/markets/stocks-thailand/market-movers-large-cap/',
#   'thailand'],
#  ['https://www.tradingview.com/markets/stocks-bangladesh/market-movers-large-cap/',
#   'bangladesh']]

# %% [markdown]
# ## This section will be concerned with defining Dictionaries that hold the value that appear on the page itself and their corresponding payload values

# %%
#This isn't done yet. Dictionarize it
dividends = {
    'title':'dividends',
    'Name':'description',
    'Currency':'fundamental_currency_code',
    'Dividends per share(FY)':'dps_common_stock_prim_issue_fy',
    'Dividends per share(FQ)':'dps_common_stock_prim_issue_fq',
    'Dividend yield %(TTM)':'dividends_yield_current',
    'Dividend yield FWD %':'dividends_yield',
    'Payout ratio %(TTM)':'dividend_payout_ratio_ttm',
    'Dividends per share growth %(Annual YoY)':'dps_common_stock_prim_issue_yoy_growth_fy',
    'Continuous dividend payout':'continuous_dividend_payout',
    'Continuous dividend growth':'continuous_dividend_growth'}

# %%
performance = {
    'title':'performance',
    'Name':'description',
    'Currency':'fundamental_currency_code',
    'Price':'close',
    'Change % 1D':'change',
    'Performance % 1W':'Perf.W',
    'Performance % 1M':'Perf.1M',
    'Performance % 3M':'Perf.3M',
    'Performance % 6M':'Perf.6M',
    'Performance % YTD':'Perf.YTD',
    'Performance % 1Y':'Perf.Y',
    'Performance % 5Y':'Perf.5Y',
    'Performance % All Time':'Perf.All',
    'Volatility 1W':'Volatility.W',
    'Volatility 1M':'Volatility.M',
   
    
    
}

# %%
valuation = {
    
    'title':'valuation',    
    'Name':'description',
    'Currency':'fundamental_currency_code',
    'Market cap':'market_cap_basic',
    'Market cap perf % 1Y':'Perf.1Y.MarketCap',
    'P/E':'price_earnings_ttm',
    'PEG (TTM)':'price_earnings_growth_ttm',
    'P/S':'price_sales_current',
    'P/B':'price_book_fq',
    'P/CF':'price_to_cash_f_operating_activities_ttm',
    'P/FCF':'price_free_cash_flow_ttm',
    'P/C':'price_to_cash_ratio',
    'EV':'enterprise_value_current',
    'EV / revenue (TTM)':'enterprise_value_to_revenue_ttm',
    'EV / EBIT (TTM)':'enterprise_value_to_ebit_ttm',
    'EV / EBITDA (TTM)':'enterprise_value_ebitda_ttm',
    
}

# %%
dividends = {
    
    'title':'dividends',
    'Name':'description',
    'Currency':'fundamental_currency_code',
    'Dividends per share (FY)':'dps_common_stock_prim_issue_fy',
    'Dividends per share (FQ)':'dps_common_stock_prim_issue_fq',
    'Dividend yield % (TTM)':'dividends_yield_current',
    'Dividend yield FWD %':'dividends_yield',
    'Payout ratio % (TTM)':'dividend_payout_ratio_ttm',
    'Dividends per share growth % (Annual YoY)':'dps_common_stock_prim_issue_yoy_growth_fy',
    'Continuous dividend payout':'continuous_dividend_payout',
    'Continuous dividend growth':'continuous_dividend_growth',
       
    
}

# %%
profitability = {
    'title':'profitability',
    'Name':'description',
                 'Currency':'fundamental_currency_code',
                 'Gross margin % (TTM)':'gross_margin_ttm',
                 'Operating margin % (TTM)':'operating_margin_ttm',
                 'Pretax margin % (TTM)':'pre_tax_margin_ttm',
                 'Net margin % (TTM)':'net_margin_ttm',
                 'Free cash flow margin % (TTM)':'free_cash_flow_margin_ttm',
                 'ROA % (TTM)':'return_on_assets_fq',
                 'ROE % (TTM)':'return_on_equity_fq',
                 'ROIC % (TTM)':'return_on_invested_capital_fq',
                 'R&D ratio (TTM)':'research_and_dev_ratio_ttm',
                 'SG&A ratio (TTM)':'sell_gen_admin_exp_other_ratio_ttm'
                }

# %%
incomeStatement = {
    'title':'incomestatement',
    'Name':'description',
                   'Currency':'fundamental_currency_code',
                   'Revenue (TTM)' : 'total_revenue_ttm',
                   'Revenue growth % (TTM YoY)':'total_revenue_yoy_growth_ttm',
                   'Gross profit (TTM)': "gross_profit_ttm",
                   'Operating income (TTM)': 'oper_income_ttm',
                   'Net income (TTM)' : 'net_income_ttm',
                   "EBITDA (TTM)":'ebitda_ttm',
                   'EPS Diluted (TTM)' : 'earnings_per_share_diluted_ttm',
                   'EPS Diluted% (TTM YoY)' : 'earnings_per_share_diluted_yoy_growth_ttm'}

# %%
balanceSheet = {
                'title':'balancesheet',
                'Name':'description',
                'Currency':'fundamental_currency_code',
                'Assets (FQ)':'total_assets_fq',
                'Current assets (FQ)':'total_current_assets_fq',
                'Cash on hand (FQ)': 'cash_n_short_term_invest_fq',
                'Liabilities (FQ)':'total_liabilities_fq',
                'Debt (FQ)': 'total_debt_fq',
                'Net debt (FQ)': 'net_debt_fq',
                'Equity':'total_equity_fq',
                'Current ratio (FQ)':'current_ratio_fq',
                'Quick ratio (FQ)':'quick_ratio_fq',
                'Debt / equity (FQ)':'debt_to_equity_fq',
                'Cash / debt (FQ)':'cash_n_short_term_invest_to_total_debt_fq'
               }

# %%
len(balanceSheet)
# Out:
# 14

# %%
cashFlow = {
    
    'title':'cashflow',
    'Name':'description',
            'Currency':'fundamental_currency_code',
            'Operating CF (TTM)':'cash_f_operating_activities_ttm',
            'Investing CF (TTM)':'cash_f_investing_activities_ttm',
            'Financing CF (TTM)':'cash_f_financing_activities_ttm',
           'Free cash flow (TTM)':'free_cash_flow_ttm',
            'CAPEX (TTM)': 'capital_expenditures_ttm'
           }

# %%
oscillators = {
    
    'title':'oscillators',
    'Name':'description',
    'Oscillators Rating 1D':'Recommend.Other',
    'RSI (14) 1D':'RSI',
    'Momentum (10) 1D':'Mom',
    'Awesome Oscillator 1D':'AO',
    'Commodity Channel Index (20) 1D':'CCI20',
    'Stochastic (14,3,3) 1D %K':'Stoch.K',
    'Stochastic (14,3,3) 1D %D':'Stoch.D',
    'MACD (12,26) 1D Level' : 'MACD.macd',
    'MACD (12,26) 1D Signal':'MACD.signal'
              }

# %%
trendFollowing = {
    
    'title':'trendfollowing',
    'Name':'description',
    'Currency':'fundamental_currency_code',
    'MA Rating 1D':'Recommend.MA',
    'Price':'close',
    'Moving Average (20) 1D':'SMA20',
    'Moving Average (50) 1D':'SMA50',
    'Moving Average (200) 1D':'SMA200',
    'Bollinger Bands (20) 1D Upper':'BB.upper',
    'Bollinger Bands (20) 1D Lower':'BB.lower',
    
    
    
}

# %%
dictsList = [performance, dividends, oscillators, cashFlow, trendFollowing,incomeStatement , balanceSheet, valuation]

# %% [markdown]
# ## This section will be concerned with dealing with the api

# %%
def getCountryTable(payloadPath, country, reqRows = 30000):
    
    with open(payloadPath, 'r') as f:
        
        conn = http.client.HTTPSConnection("scanner.tradingview.com")
        payloadString = f.read()
        payloadString = payloadString.replace("\"range\":[0,100]","\"range\":[0,{}]".format(reqRows))
    
    conn.request("POST", "/{}/scan".format(country), payloadString)
    #print("scanner.tradingview.com"+"/{}/scan".format(country))
    res = conn.getresponse()
    data = res.read()
    
    
    return json.loads(data)

# %%
uk_table = getCountryTable((basePath + 'jsonFiles\\ActualFiles\\canadaOscillatorsPayload.json'), 'uk', 20000)
uk_table
# Out:
# {'totalCount': 1104,
#  'data': [{'s': 'LSE:SHEL',
#    'd': ['SHELL PLC ORD EUR0.07',
#     -0.09090909,
#     44.79062963,
#     -99.8934,
#     9.62648529,
#     -175.72406144,
#     13.77600486,
#     23.09551217,
#     7.83005345,
#     24.50048176]},
#   {'s': 'LSE:AZN',
#    'd': ['ASTRAZENECA ORD USD0.25',
#     -0.18181818,
#     42.80230879,
#     -258,
#     -427.19425,
#     -52.38992991,
#     30.47358435,
#     23.75045517,
#     -155.92110881,
#     -150.52388025]},
#   {'s': 'LSE:HSBA',
#    'd': ['HSBC HOLDINGS PLC ORD USD0.50',
#     -0.27272727,
#     44.35149005,
#     -6.01508,
#     -25.65494888,
#     -37.27859256,
#     41.99677393,
#     34.75634122,
#     -8.08714667,
#     -7.50260952]},
#   {'s': 'LSE:ULVR',
#    'd': ['UNILEVER PLC ORD GBP0.031111',
#     -0.18181818,
#     43.63452305,
#     -121.51,
#     -86.25156471,
#     -43.48820535,
#     33.47083333,
#     30.53194444,
#     -34.78118504,
#     -33.94801658]},
#   {'s': 'LSE:RIO',
#    'd': ['RIO TINTO ORD GBP0.10',
#     0.09090909,
#     56.35489583,
#     100,
#     193.13238088,
#     50.68130495,
#     73.4226689,
#     78.67765709,
#     63.5899802,
#     52.38365041]},
#   {'s': 'LSE:BP.',
#    'd': ['BP ORD USD0.25',
#     0.18181818,
#     30.72612815,
#     -52.70001,
#     -33.95636768,
#     -127.82021045,
#     5.33277251,
#     7.41658868,
#     -10.34101562,
#     -3.82828244]},
#   {'s': 'LSE:DGE',
#    'd': ['DIAGEO ORD GBP0.28 101/108',
#     0,
#     61.38212045,
#     63,
#     87.86934706,
#     154.11047344,
#     85.99840891,
#     84.99132593,
#     20.44164012,
#     5.89442441]},
#   {'s': 'LSE:GSK',
#    'd': ['GSK PLC ORD GBP0.3125',
#     -0.18181818,
#     41.88108946,
#     -59.1789,
#     -71.91017088,
#     -74.02303461,
#     30.56878037,
#     23.63070845,
#     -18.13061029,
#     -12.39551921]},
#   {'s': 'LSE:BATS',
#    'd': ['BRITISH AMERICAN TOBACCO ORD GBP0.25',
#     -0.09090909,
#     54.88997359,
#     72,
#     -3.54769382,
#     123.98618858,
#     85.49989156,
#     87.23429848,
#     -8.00542332,
#     -21.84985536]},
#   {'s': 'LSE:REL',
#    'd': ['RELX PLC GBP0.1444',
#     -0.18181818,
#     59.5005686,
#     43.4,
#     29.47401765,
#     94.20427627,
#     75.38341938,
#     60.33280472,
#     20.63604898,
#     22.82015536]},
#   {'s': 'LSE:GLEN',
#    'd': ['GLENCORE PLC ORD USD0.01',
#     -0.27272727,
#     41.85501247,
#     -8.89999,
#     -10.42246197,
#     -101.8663754,
#     31.97705716,
#     36.64217483,
#     -4.13957135,
#     -2.9953917]},
#   {'s': 'LSE:LSEG',
#    'd': ['LONDON STOCK EXCHANGE GROUP ORD GBP0.06918604',
#     -0.18181818,
#     61.76583051,
#     160,
#     109.6265,
#     179.66142793,
#     87.76085683,
#     80.74157306,
#     43.62596614,
#     21.70612811]},
#   {'s': 'LSE:RKT',
#    'd': ['RECKITT BENCKISER GROUP PLC ORD GBP0.10',
#     0,
#     38.01800029,
#     -202.796,
#     -240.56402059,
#     -75.06153246,
#     15.37072749,
#     12.50889129,
#     -90.72349928,
#     -66.16266146]},
#   {'s': 'LSE:NG.',
#    'd': ['NATIONAL GRID ORD GBP0.12431289',
#     -0.09090909,
#     44.86158405,
#     -9.80002,
#     15.87915621,
#     -43.1646041,
#     50.95168633,
#     63.63905886,
#     2.21974733,
#     1.45209226]},
#   {'s': 'LSE:CPG',
#    'd': ['COMPASS GROUP PLC ORD GBP0.1105',
#     0,
#     53.43794808,
#     23.56,
#     24.60407941,
#     0.95508071,
#     39.52,
#     41.39555556,
#     7.66832326,
#     9.21015751]},
#   {'s': 'LSE:BA.',
#    'd': ['BAE SYSTEMS ORD GBP0.025',
#     -0.18181818,
#     55.65432311,
#     -10,
#     36.39630706,
#     -4.79663925,
#     48.47222222,
#     51.34259259,
#     14.43496255,
#     17.26625955]},
#   {'s': 'LSE:HLN',
#    'd': ['HALEON PLC ORD GBP0.01',
#     -0.18181818,
#     45.01529234,
#     -9.32749,
#     -9.90434176,
#     -60.82066482,
#     41.99265571,
#     32.86067116,
#     -2.49715754,
#     -1.61786898]},
#   {'s': 'LSE:AAL',
#    'd': ['ANGLO AMERICAN USD0.54945',
#     -0.09090909,
#     46.96254403,
#     46.4975,
#     -5.94955882,
#     -23.0304033,
#     63.41213323,
#     67.98266096,
#     -8.45293828,
#     -14.44461253]},
#   {'s': 'LSE:LLOY',
#    'd': ['LLOYDS BANKING GROUP ORD GBP0.1',
#     -0.09090909,
#     49.98169204,
#     0.475001,
#     -0.66724953,
#     5.58644821,
#     67.4816018,
#     63.55273088,
#     -0.30403929,
#     -0.47257585]},
#   {'s': 'LSE:PRU',
#    'd': ['PRUDENTIAL GBP0.05',
#     -0.09090909,
#     53.11043645,
#     53.40002,
#     17.37280212,
#     65.93535306,
#     81.21693266,
#     83.365162,
#     -0.59545717,
#     -8.42552776]},
#   {'s': 'LSE:EXPN',
#    'd': ['EXPERIAN PLC ORD USD0.10',
#     0,
#     53.85024811,
#     233,
#     -37.78719412,
#     20.48056765,
#     78.03183639,
#     71.64842652,
#     -26.42450224,
#     -48.15266394]},
#   {'s': 'LSE:AHT',
#    'd': ['ASHTEAD GROUP ORD GBP0.10',
#     0,
#     53.21476446,
#     206,
#     24.19664706,
#     56.04983392,
#     78.04107425,
#     79.27143176,
#     -28.35094949,
#     -66.46209333]},
#   {'s': 'LSE:VOD',
#    'd': ['VODAFONE GROUP ORD USD0.2095238',
#     0,
#     53.84543521,
#     3.739998,
#     0.56610475,
#     51.81945468,
#     85.56380236,
#     88.12764344,
#     0.31250315,
#     0.03714566]},
#   {'s': 'LSE:BARC',
#    'd': ['BARCLAYS PLC ORD GBP0.25',
#     0.18181818,
#     39.26073364,
#     2.5633,
#     -12.05198094,
#     -41.47231414,
#     33.79600841,
#     30.10370316,
#     -4.73531869,
#     -5.0390499]},
#   {'s': 'LSE:TSCO',
#    'd': ['TESCO ORD GBP0.0633333',
#     0.18181818,
#     61.05016626,
#     5.30001,
#     3.02111174,
#     124.41984829,
#     70.47126392,
#     65.55835796,
#     1.51294563,
#     1.34005296]},
#   {'s': 'LSE:III',
#    'd': ['3I GROUP ORD GBP0.738636',
#     0.27272727,
#     50.4548281,
#     10.989,
#     -23.47674265,
#     -30.86495511,
#     52.54650363,
#     44.31040322,
#     -9.40924542,
#     -9.66333849]},
#   {'s': 'LSE:RR.',
#    'd': ['ROLLS ROYCE HOLDINGS ORD GBP0.20',
#     0.27272727,
#     71.02835745,
#     31.3,
#     11.71341318,
#     170.46252961,
#     96.47811254,
#     92.65070752,
#     3.85763951,
#     0.77269782]},
#   {'s': 'LSE:SSE',
#    'd': ['SSE PLC GBP0.50',
#     0,
#     51.01628187,
#     17.5,
#     67.70146765,
#     40.84964432,
#     65.09803922,
#     76.65532421,
#     17.13266981,
#     11.1519216]},
#   {'s': 'LSE:NWG',
#    'd': ['NATWEST GROUP PLC ORD GBP1.0769',
#     0.09090909,
#     40.03245803,
#     -11.49941,
#     -27.17182468,
#     -35.72132952,
#     42.60359979,
#     35.26498322,
#     -10.45956801,
#     -10.55775863]},
#   {'s': 'LSE:ABF',
#    'd': ['ASSOCIATED BRITISH FOODS ORD 5 15/22P',
#     0.18181818,
#     79.74415837,
#     341.86,
#     146.51414559,
#     227.17600577,
#     90.54226225,
#     88.54708065,
#     53.42020286,
#     17.49259846]},
#   {'s': 'LSE:STAN',
#    'd': ['STANDARD CHARTERED PLC ORD USD0.50',
#     -0.18181818,
#     30.02320121,
#     -93.6,
#     -87.59394603,
#     -74.39785956,
#     21.03158699,
#     20.78013264,
#     -32.47026271,
#     -27.7595774]},
#   {'s': 'LSE:IMB',
#    'd': ['IMPERIAL BRANDS PLC GBP0.10',
#     -0.18181818,
#     64.04019792,
#     67,
#     76.92311912,
#     131.21192378,
#     88.0952381,
#     88.92466354,
#     22.26420798,
#     14.30356166]},
#   {'s': 'LSE:LGEN',
#    'd': ['LEGAL & GENERAL GROUP ORD GBP0.025',
#     0,
#     55.44148312,
#     12.772,
#     4.67513297,
#     56.54344445,
#     79.40088667,
#     84.60375304,
#     0.72753086,
#     -0.88681004]},
#   {'s': 'LSE:ANTO',
#    'd': ['ANTOFAGASTA ORD GBP0.05',
#     -0.18181818,
#     38.72814816,
#     -46.5,
#     -33.38107647,
#     -139.63556017,
#     26.34066007,
#     39.40849441,
#     -21.77592488,
#     -20.24719521]},
#   {'s': 'LSE:CCL',
#    'd': ['CARNIVAL PLC ORD USD1.66',
#     0.18181818,
#     52.20967788,
#     80.36852,
#     -25.0944555,
#     92.00820174,
#     77.80256448,
#     75.83041807,
#     -22.27781055,
#     -37.79609523]},
#   {'s': 'LSE:BT.A',
#    'd': ['BT GROUP ORD GBP0.05',
#     -0.36363636,
#     62.23589824,
#     10.9997,
#     5.33095588,
#     100.91770825,
#     88.63041882,
#     89.70016567,
#     1.52223019,
#     0.20048426]},
#   {'s': 'LSE:RTO',
#    'd': ['RENTOKIL INITIAL ORD GBP0.01',
#     0.18181818,
#     32.49325526,
#     -9.80001,
#     -91.34400376,
#     -42.11602543,
#     38.21689879,
#     29.72013244,
#     -38.33773938,
#     -40.20240438]},
#   {'s': 'LSE:AV.',
#    'd': ['AVIVA ORD GBP0.328947368',
#     -0.09090909,
#     57.05321095,
#     9.90001,
#     5.40994362,
#     4.36159796,
#     76.62115282,
#     73.48505485,
#     2.49667384,
#     2.21870082]},
#   {'s': 'LSE:SGE',
#    'd': ['SAGE GROUP GBP0.01051948',
#     0,
#     50.91135616,
#     18.20001,
#     -7.99277209,
#     1.09674443,
#     52.41320972,
#     43.36379158,
#     -3.74879869,
#     -4.92439683]},
#   {'s': 'LSE:INF',
#    'd': ['INFORMA PLC ORD GBP0.001',
#     0,
#     51.20941733,
#     13.20002,
#     -2.60716062,
#     49.75827533,
#     73.95833496,
#     75.19840964,
#     -2.4627324,
#     -4.96913583]},
#   {'s': 'LSE:WISE',
#    'd': ['WISE PLC CLS A ORD GBP0.01',
#     0.18181818,
#     53.3238626,
#     16.5151,
#     3.27902109,
#     40.29629557,
#     75.12584248,
#     69.06643312,
#     -0.98628105,
#     -2.63752788]},
#   {'s': 'LSE:BNZL',
#    'd': ['BUNZL ORD GBP0.32142857',
#     -0.09090909,
#     50.52299448,
#     59,
#     1.31127353,
#     -19.57040766,
#     68.7654321,
#     69.24215883,
#     0.64533259,
#     2.53921312]},
#   {'s': 'LSE:IHG',
#    'd': ['INTERCONTINENTAL HOTELS GROUP ORD GBP0.208521303',
#     -0.18181818,
#     46.15762819,
#     -54,
#     -152.01008088,
#     -45.79629363,
#     38.37739234,
#     29.12884682,
#     -59.28045895,
#     -51.35014537]},
#   {'s': 'LSE:NXT',
#    'd': ['NEXT ORD GBP0.10',
#     0.18181818,
#     61.55577274,
#     512,
#     204.75439706,
#     145.81395025,
#     78.30629128,
#     77.06565733,
#     60.42948335,
#     4.83547182]},
#   {'s': 'LSE:SN.',
#    'd': ['SMITH & NEPHEW ORD USD0.20',
#     -0.27272727,
#     60.44153247,
#     70.20001,
#     18.47164465,
#     134.90072822,
#     87.07495375,
#     85.22694806,
#     -3.55958032,
#     -16.6402773]},
#   {'s': 'LSE:CNA',
#    'd': ['CENTRICA ORD GBP0.061728395',
#     -0.09090909,
#     39.36484038,
#     -8.07499,
#     -2.25924691,
#     -274.78112667,
#     10.36400441,
#     15.15013048,
#     -0.98784448,
#     -0.15484169]},
#   {'s': 'LSE:SVT',
#    'd': ['SEVERN TRENT ORD GBP0.9789',
#     0,
#     60.65815254,
#     58,
#     189.18994118,
#     54.66381374,
#     68.07017544,
#     73.45068488,
#     65.26111604,
#     63.15710989]},
#   {'s': 'LSE:WPP',
#    'd': ['WPP PLC ORD GBP0.10',
#     0.09090909,
#     48.87771503,
#     25.1806,
#     9.77383868,
#     15.49964473,
#     66.72975191,
#     75.79500824,
#     -2.76629377,
#     -6.91602515]},
#   {'s': 'LSE:ADM',
#    'd': ['ADMIRAL GROUP ORD GBP0.001',
#     -0.09090909,
#     65.8669105,
#     49,
#     74.18338529,
#     134.686966,
#     70.04590164,
#     66.30923757,
#     29.17964248,
#     24.39737]},
#   {'s': 'LSE:UU.',
#    'd': ['UNITED UTILITIES GROUP PLC ORD GBP0.05',
#     -0.18181818,
#     62.99152997,
#     18.5,
#     73.37281882,
#     54.58469182,
#     67.28277059,
#     72.6222018,
#     26.49286529,
#     26.55845253]},
#   {'s': 'LSE:HLMA',
#    'd': ['HALMA ORD GBP0.10',
#     0.09090909,
#     50.27576263,
#     64.3242,
#     -5.18691912,
#     73.24917966,
#     76.87004525,
#     76.35471837,
#     -19.68637045,
#     -33.47303048]},
#   {'s': 'LSE:JD.',
#    'd': ['JD SPORTS FASHION PLC ORD GBP0.0005',
#     0,
#     52.47487349,
#     8.15,
#     -4.86877459,
#     78.34115106,
#     75.48058392,
#     56.23916416,
#     -1.87298588,
#     -3.00544467]},
#   {'s': 'LSE:MRO',
#    'd': ['MELROSE INDUSTRIES PLC ORD GBP0.22857142',
#     0.09090909,
#     72.37279435,
#     46.61829,
#     27.54012521,
#     178.30137305,
#     91.6458035,
#     88.31091064,
#     7.34357031,
#     1.21097978]},
#   {'s': 'LSE:PSON',
#    'd': ['PEARSON ORD GBP0.25',
#     -0.09090909,
#     72.19839136,
#     45.4,
#     54.23070176,
#     110.9423165,
#     76.95389883,
#     73.23535247,
#     20.97159957,
#     18.52678544]},
#   {'s': 'LSE:MNDI',
#    'd': ['MONDI PLC ORD EUR0.20',
#     -0.18181818,
#     55.53519448,
#     75,
#     9.42131029,
#     33.69865392,
#     86.20735446,
#     83.49231816,
#     2.78512838,
#     -3.34632143]},
#   {'s': 'LSE:SBRY',
#    'd': ['SAINSBURY(J) ORD GBP0.28571428',
#     0.09090909,
#     64.18236774,
#     19.3,
#     14.09362026,
#     113.21580242,
#     63.53317404,
#     67.20862134,
#     3.11235015,
#     0.80130348]},
#   {'s': 'LSE:WTB',
#    'd': ['WHITBREAD ORD GBP0.76797385',
#     0.18181818,
#     47.07818218,
#     12,
#     -58.05559118,
#     -5.29091295,
#     36.11474015,
#     27.96850613,
#     -28.02641298,
#     -35.3561124]},
#   {'s': 'LSE:CRDA',
#    'd': ['CRODA INTERNATIONAL ORD GBP0.10609756',
#     0,
#     51.19703243,
#     346,
#     -4.47570441,
#     92.19402464,
#     78.48904268,
#     82.29817645,
#     -56.06514656,
#     -116.97480453]},
#   {'s': 'LSE:ITRK',
#    'd': ['INTERTEK GROUP ORD GBP0.01',
#     -0.18181818,
#     38.63265021,
#     -148,
#     -183.734625,
#     -62.55240711,
#     29.2861243,
#     27.33033941,
#     -78.0083357,
#     -74.24548096]},
#   {'s': 'LSE:SDR',
#    'd': ['SCHRODERS PLC',
#     0,
#     48.25963671,
#     20.40001,
#     -2.98800515,
#     12.99459765,
#     66.92305983,
#     72.11638622,
#     -3.97681936,
#     -6.78099204]},
#   {'s': 'LSE:SPX',
#    'd': ['SPIRAX-SARCO ENGINEERING ORD GBP0.269230769',
#     0.09090909,
#     41.66570692,
#     298,
#     -330.09643206,
#     19.49893547,
#     76.09860665,
#     79.53740303,
#     -210.31422672,
#     -286.56939863]},
#   {'s': 'LSE:BRBY',
#    'd': ['BURBERRY GROUP ORD GBP0.0005',
#     0.18181818,
#     30.50728869,
#     -28.5,
#     -76.29196912,
#     -97.74635556,
#     26.05653933,
#     32.81213953,
#     -51.80115715,
#     -61.85215747]},
#   {'s': 'LSE:ENT',
#    'd': ['ENTAIN PLC ORD EUR0.01',
#     0.18181818,
#     55.11846037,
#     51.60002,
#     -8.31206124,
#     164.42727061,
#     77.31896648,
#     61.2307678,
#     -15.65459414,
#     -25.61393961]},
#   {'s': 'LSE:AUTO',
#    'd': ['AUTO TRADER GROUP PLC ORD GBP0.01',
#     0,
#     56.6180396,
#     21.99998,
#     4.57172938,
#     53.83256049,
#     68.42108995,
#     63.5661629,
#     1.46452749,
#     -0.13689401]},
#   {'s': 'LSE:SMIN',
#    'd': ['SMITHS GROUP PLC ORD GBP0.375',
#     0,
#     54.87633811,
#     63,
#     10.10131618,
#     43.05584723,
#     79.08496732,
#     81.75782594,
#     1.27231713,
#     -5.85680411]},
#   {'s': 'LSE:BME',
#    'd': ['B & M EUROPEAN VALUE RETAIL SA ORD GBP0.1 (DI)',
#     0.18181818,
#     46.08398694,
#     -13.19998,
#     -21.25201712,
#     -41.05042867,
#     33.61973362,
#     27.45088034,
#     -8.95366468,
#     -9.1662073]},
#   {'s': 'LSE:MNG',
#    'd': ['M&G PLC ORD 5',
#     0.09090909,
#     57.98837662,
#     10.9,
#     5.07303915,
#     92.23870409,
#     85.91713194,
#     86.6465177,
#     1.7038163,
#     0.79951654]},
#   {'s': 'LSE:PHNX',
#    'd': ['PHOENIX GROUP HOLDINGS PLC ORD GBP0.10',
#     -0.09090909,
#     47.3835666,
#     18.44921,
#     -1.56258268,
#     20.79225372,
#     72.12580325,
#     79.27738161,
#     -4.78908098,
#     -8.69701939]},
#   {'s': 'LSE:WEIR',
#    'd': ['WEIR GROUP ORD GBP0.125',
#     0.09090909,
#     47.66951063,
#     16,
#     -56.34125,
#     -8.16583435,
#     72.46968121,
#     62.6198095,
#     -25.66464456,
#     -32.59724037]},
#   {'s': 'LSE:BKG',
#    'd': ['BERKELEY GROUP HLDGS ORD GBP0.054141',
#     0,
#     62.54718063,
#     278,
#     134.65485441,
#     132.59820057,
#     83.2034632,
#     82.45137811,
#     38.95022289,
#     9.73665169]},
#   {'s': 'LSE:OCDO',
#    'd': ['OCADO GROUP PLC ORD GBP0.02',
#     0.09090909,
#     51.06570417,
#     88.46,
#     -12.08762744,
#     103.16616597,
#     73.95929008,
#     73.18791913,
#     -22.08430634,
#     -38.0016731]},
#   {'s': 'LSE:MKS',
#    'd': ['MARKS & SPENCER GROUP ORD GBP0.01',
#     0.27272727,
#     73.04601187,
#     32.69999,
#     2.48657903,
#     386.99255143,
#     71.93186544,
#     62.96033305,
#     1.70349544,
#     -0.83131479]},
#   {'s': 'LSE:BDEV',
#    'd': ['BARRATT DEVELOPMENTS ORD GBP0.10',
#     -0.09090909,
#     64.34569585,
#     47.69999,
#     12.79334041,
#     150.86088083,
#     91.52609257,
#     91.32685185,
#     3.61393614,
#     -2.7672928]},
#   {'s': 'LSE:AAF',
#    'd': ['AIRTEL AFRICA PLC ORD USD0.5',
#     0.18181818,
#     45.26928643,
#     1.4,
#     -2.17498676,
#     -30.30328331,
#     57.68115942,
#     68.11594203,
#     -0.94250014,
#     -1.26541906]},
#   {'s': 'LSE:DPH',
#    'd': ['DECHRA PHARMACEUTICALS ORD GBP0.01',
#     0.27272727,
#     47.01083516,
#     24,
#     1.90676324,
#     -6.32030111,
#     76.11940299,
#     77.77777778,
#     -1.57833888,
#     -1.60606353]},
#   {'s': 'LSE:CTEC',
#    'd': ['CONVATEC GROUP PLC ORD GBP0.1',
#     0.18181818,
#     55.46759384,
#     7.80041,
#     0.89312662,
#     117.92805522,
#     79.8205045,
#     82.02596274,
#     -0.70820265,
#     -2.36547027]},
#   {'s': 'LSE:KGF',
#    'd': ['KINGFISHER ORD GBP0.157142857',
#     0.09090909,
#     56.71400384,
#     16,
#     6.33905471,
#     104.98102451,
#     68.62743945,
#     74.4395446,
#     0.4409418,
#     -1.87337416]},
#   {'s': 'LSE:TW.',
#    'd': ['TAYLOR WIMPEY ORD GBP0.01',
#     0,
#     59.14823737,
#     8.685,
#     1.39367059,
#     154.62966834,
#     85.11052657,
#     87.23773695,
#     0.25284296,
#     -0.8229095]},
#   {'s': 'LSE:FRES',
#    'd': ['FRESNILLO PLC ORD USD0.50',
#     0,
#     49.17840125,
#     14.8,
#     8.49420585,
#     23.66929093,
#     63.72548283,
#     70.31225127,
#     0.29705582,
#     -1.25964649]},
#   {'s': 'LSE:INVP',
#    'd': ['INVESTEC ORD GBP0.0002',
#     0.18181818,
#     62.68245182,
#     42.79999,
#     11.60266256,
#     68.80603941,
#     79.02321653,
#     81.22360826,
#     4.08779003,
#     0.00279223]},
#   {'s': 'LSE:SMDS',
#    'd': ['SMITH(DS) ORD GBP0.10',
#     -0.27272727,
#     59.46146981,
#     20.69999,
#     9.01666412,
#     88.9728968,
#     90.78237878,
#     92.213055,
#     2.04230679,
#     -0.40979562]},
#   {'s': 'LSE:ICP',
#    'd': ['INTERMEDIATE CAPITAL GROUP PLC ORD GBP0.2625',
#     0.18181818,
#     59.26365384,
#     78.2493,
#     32.61617647,
#     84.11379491,
#     75.61921171,
#     79.36725932,
#     10.9090303,
#     1.35296723]},
#   {'s': 'LSE:DPLM',
#    'd': ['DIPLOMA PLC ORD GBP0.05',
#     0.18181818,
#     55.31329018,
#     144,
#     23.93923235,
#     89.91610178,
#     75.69158653,
#     72.93798364,
#     -9.06484946,
#     -29.88513581]},
#   {'s': 'LSE:HIK',
#    'd': ['HIKMA PHARMACEUTICALS ORD GBP0.10',
#     0.18181818,
#     21.90331755,
#     -198.5,
#     -187.75301324,
#     -149.5868242,
#     4.9152956,
#     4.11757188,
#     -72.3793886,
#     -55.2289414]},
#   {'s': 'LSE:IMI',
#    'd': ['IMI ORD GBP0.28571428',
#     0.09090909,
#     51.77354583,
#     43,
#     -19.79323529,
#     5.9485904,
#     65.60600144,
#     56.81446118,
#     -7.95767205,
#     -11.79090875]},
#   {'s': 'LSE:BEZ',
#    'd': ['BEAZLEY PLC (UK) ORD GBP0.05',
#     0.27272727,
#     68.82008075,
#     55.5,
#     7.05557338,
#     280.80653837,
#     83.62801378,
#     80.86654347,
#     2.82101222,
#     -3.55873705]},
#   {'s': 'LSE:RMV',
#    'd': ['RIGHTMOVE ORD GBP0.001',
#     0,
#     25.44695812,
#     -22.29999,
#     -63.81222241,
#     -72.02139727,
#     8.51396888,
#     6.18817893,
#     -25.05077608,
#     -22.76105256]},
#   {'s': 'LSE:0I8A',
#    'd': ['DENBURY INC COM USD0.001',
#     -0.18181818,
#     44.21614847,
#     -2.419899,
#     -3.69074794,
#     -63.32716545,
#     14.32819363,
#     14.76563722,
#     -0.90264455,
#     -0.37968211]},
#   {'s': 'LSE:PSN',
#    'd': ['PERSIMMON ORD GBP0.10',
#     0.27272727,
#     66.63531005,
#     189.59998,
#     61.07550868,
#     173.46947917,
#     89.39641102,
#     87.57228893,
#     20.66800522,
#     1.28553396]},
#   {'s': 'LSE:STJ',
#    'd': ["ST JAMES'S PLACE ORD GBP0.15",
#     0,
#     38.06411865,
#     40.00001,
#     -61.03285009,
#     -7.89739435,
#     72.94284665,
#     73.91795565,
#     -33.01471039,
#     -42.65950293]},
#   {'s': 'LSE:HWDN',
#    'd': ['HOWDEN JOINERY GROUP PLC ORD GBP0.10',
#     0.18181818,
#     42.2200272,
#     15.2,
#     -38.08233682,
#     -4.0871779,
#     58.28289593,
#     48.46452869,
#     -15.61031856,
#     -18.96891324]},
#   {'s': 'LSE:FRAS',
#    'd': ['FRASERS GROUP PLC ORD GBP0.10',
#     0.09090909,
#     63.07683833,
#     42.125,
#     16.92570574,
#     178.13767723,
#     67.74710666,
#     69.31070051,
#     5.57628525,
#     1.87732597]},
#   {'s': 'LSE:HL.',
#    'd': ['HARGREAVES LANSDOWN ORD GBP0.004',
#     0,
#     41.1268555,
#     9.40001,
#     -18.47678415,
#     -51.29482687,
#     54.8333,
#     66.05980787,
#     -9.96669806,
#     -13.27260387]},
#   {'s': 'LSE:GAW',
#    'd': ['GAMES WORKSHOP GROUP ORD GBP0.05',
#     0.18181818,
#     60.56861687,
#     640,
#     238.47007647,
#     146.27096928,
#     75.78772803,
#     75.65939148,
#     36.50747422,
#     -58.07044946]},
#   {'s': 'LSE:HSX',
#    'd': ['HISCOX ORD GBP0.065 (DI)',
#     0.27272727,
#     60.23823679,
#     37,
#     -10.24394962,
#     154.69634961,
#     66.71259089,
#     54.69281713,
#     -4.16503017,
#     -9.93182301]},
#   {'s': 'LSE:RS1',
#    'd': ['RS GROUP PLC ORD GBP0.10',
#     -0.18181818,
#     47.43144863,
#     28.99998,
#     -26.40426329,
#     2.64254618,
#     77.97586896,
#     65.69698371,
#     -8.71403474,
#     -12.15925873]},
#   {'s': 'LSE:SXS',
#    'd': ['SPECTRIS ORD GBP0.05',
#     0.27272727,
#     57.99766287,
#     295,
#     0.86263088,
#     83.13282924,
#     91.31342712,
#     88.72735498,
#     -11.41210332,
#     -46.391913]},
#   {'s': 'LSE:EZJ',
#    'd': ['EASYJET ORD GBP0.27285714',
#     0.09090909,
#     55.52937002,
#     36.40001,
#     -7.43592803,
#     95.07281183,
#     78.26085696,
#     74.65928896,
#     -5.73748546,
#     -11.38369885]},
#   {'s': 'LSE:ABDN',
#    'd': ['ABRDN PLC ORD GBP0.1396825396',
#     0.18181818,
#     56.5729007,
#     12,
#     6.18437218,
#     65.49594475,
#     66.66665113,
#     73.57601895,
#     1.18114348,
#     -0.20752121]},
#   {'s': 'LSE:JMAT',
#    'd': ['JOHNSON MATTHEY ORD GBP1.109245',
#     -0.18181818,
#     45.87930613,
#     64.5,
#     -2.59484853,
#     29.64247739,
#     58.25734549,
#     68.10415747,
#     -16.00558816,
#     -28.19699149]},
#   {'s': 'LSE:CCC',
#    'd': ['COMPUTACENTER ORD GBP0.075555',
#     -0.18181818,
#     58.65072984,
#     86,
#     41.97799235,
#     12.87890999,
#     66.07969577,
#     66.93810626,
#     27.45131988,
#     28.19601521]},
#   {'s': 'LSE:INCH',
#    'd': ['INCHCAPE ORD GBP0.10',
#     0.18181818,
#     42.32181483,
#     18.5,
#     -31.38507971,
#     -67.17846235,
#     37.94186689,
#     47.24651467,
#     -16.44653031,
#     -19.34300863]},
#   {'s': 'LSE:BWY',
#    'd': ['BELLWAY GBP0.125',
#     0.27272727,
#     59.77455827,
#     210,
#     12.81934559,
#     86.16959531,
#     88.66907961,
#     82.37958117,
#     6.01749964,
#     -14.56048563]},
#   {'s': 'LSE:ITV',
#    'd': ['ITV ORD GBP0.10',
#     -0.09090909,
#     37.94011881,
#     -0.239998,
#     -1.71666638,
#     -130.69851194,
#     55.66418631,
#     67.59882471,
#     -1.05905394,
#     -1.29177787]},
#   {'s': 'LSE:VTY',
#    'd': ['VISTRY GROUP PLC GBP0.50',
#     0.09090909,
#     52.68887047,
#     80.5,
#     -38.29710094,
#     81.6106766,
#     84.83300899,
#     78.89413748,
#     -16.53814581,
#     -26.8705476]},
#   {'s': 'LSE:ROR',
#    'd': ['ROTORK ORD GBP0.005',
#     0.18181818,
#     54.9456398,
#     10.39999,
#     -2.12081791,
#     4.91889948,
#     67.75367611,
#     55.36097379,
#     -1.09988149,
#     -2.07832544]},
#   {'s': 'LSE:SCT',
#    'd': ['SOFTCAT PLC ORD 005',
#     0,
#     42.87803877,
#     49.78,
#     -75.47428676,
#     -30.60710429,
#     47.87843328,
#     47.74158454,
#     -37.68254378,
#     -41.1810836]},
#   {'s': 'LSE:GRG',
#    'd': ['GREGGS ORD GBP0.02',
#     0.18181818,
#     64.89811203,
#     234.92,
#     103.389525,
#     146.57859027,
#     88.18101545,
#     87.22975896,
#     29.10092273,
#     2.18722425]},
#   {'s': 'LSE:IGG',
#    'd': ['IG GROUP HLDGS ORD GBP0.00005',
#     0.18181818,
#     58.97383604,
#     47,
#     21.59803162,
#     91.60821418,
#     78.08219178,
#     81.73139141,
#     4.20609879,
#     -0.80291785]},
#   {'s': 'LSE:EMG',
#    'd': ['MAN GROUP PLC (NEW) ORD USD0.0342857142',
#     0,
#     45.55278502,
#     2.45,
#     1.64866062,
#     -79.55714036,
#     33.26272596,
#     52.81352602,
#     0.24574859,
#     0.5661743]},
#   {'s': 'LSE:DARK',
#    'd': ['DARKTRACE PLC ORD GBP0.01',
#     0.18181818,
#     50.75797388,
#     21.8,
#     -18.12311844,
#     94.94434128,
#     61.44533524,
#     51.6390326,
#     -6.8572393,
#     -9.33124591]},
#   {'s': 'LSE:TATE',
#    'd': ['TATE & LYLE ORD GBP0.2916666667',
#     -0.09090909,
#     44.40162078,
#     6.5,
#     -17.05509468,
#     -14.85756656,
#     66.9060748,
#     65.59237806,
#     -9.82810621,
#     -12.83187067]},
#   {'s': 'LSE:N91',
#    'd': ['NINETY ONE PLC ORD 001',
#     0,
#     49.41621808,
#     3,
#     0.38780265,
#     -21.24272165,
#     49.23295011,
#     57.19430155,
#     -0.49650926,
#     -1.13316651]},
#   {'s': 'LSE:IDS',
#    'd': ['INTL DISTRIBUTIONS SVCS PLC ORD GBP0.01',
#     0.18181818,
#     43.53731319,
#     2.2,
#     -1.999922,
#     -56.95611939,
#     21.61836532,
#     39.22349309,
#     -1.73023733,
#     -1.74789186]},
#   {'s': 'LSE:ROO',
#    'd': ['DELIVEROO PLC CLASS A ORD GBP0.005',
#     0,
#     68.14649639,
#     15.356,
#     14.75126153,
#     142.95786129,
#     78.82295482,
#     79.51701066,
#     4.58229995,
#     3.09280247]},
#   {'s': 'LSE:DLG',
#    'd': ['DIRECT LINE INSURANCE GROUP PLC ORD GBP0.109090909',
#     0.09090909,
#     61.69154602,
#     13.59999,
#     -1.71712912,
#     212.24603133,
#     72.18381843,
#     58.52251823,
#     -0.4667404,
#     -2.20147251]},
#   {'s': 'LSE:RSW',
#    'd': ['RENISHAW ORD GBP0.20',
#     -0.09090909,
#     32.7025883,
#     -58,
#     -246.23680882,
#     -75.29262908,
#     35.69286215,
#     34.05304132,
#     -117.94458017,
#     -121.16739874]},
#   {'s': 'LSE:INDV',
#    'd': ['INDIVIOR PLC ORD USD0.5',
#     -0.09090909,
#     41.06011377,
#     -83.559,
#     -42.02320294,
#     -52.93059127,
#     39.92919132,
#     51.90276134,
#     -27.86690052,
#     -32.47014201]},
#   {'s': 'LSE:VMUK',
#    'd': ['VIRGIN MONEY UK PLC ORD GBP0.10',
#     0.27272727,
#     57.74193491,
#     12.4,
#     0.50366135,
#     95.72334082,
#     83.47819494,
#     76.49489969,
#     -0.55847273,
#     -1.99467551]},
#   {'s': 'LSE:BVIC',
#    'd': ['BRITVIC ORD GBP0.2',
#     0,
#     53.41439174,
#     5.5,
#     8.03991662,
#     79.08549714,
#     62.62626263,
#     68.84164223,
#     0.64849729,
#     -2.5696964]},
#   {'s': 'LSE:NETW',
#    'd': ['NETWORK INTL HLDGS PLC ORD GBP0.10',
#     0.18181818,
#     64.25900762,
#     5.6,
#     0.5907665,
#     109.07346078,
#     84.93029363,
#     76.54774386,
#     0.34877559,
#     -0.11183432]},
#   {'s': 'LSE:DNLM',
#    'd': ['DUNELM GROUP PLC ORD GBP0.01',
#     -0.09090909,
#     51.40278843,
#     20,
#     -2.35915176,
#     30.65477027,
#     66.85288222,
#     64.38163438,
#     -8.8253798,
#     -15.27389287]},
#   {'s': 'LSE:BAB',
#    'd': ['BABCOCK INTERNATIONAL GROUP ORD GBP0.60',
#     0,
#     47.86959097,
#     4.39999,
#     1.84007018,
#     -81.88843993,
#     26.12617117,
#     42.25387494,
#     -0.31852647,
#     0.5100944]},
#   {'s': 'LSE:PNN',
#    'd': ['PENNON GROUP ORD GBP0.6105',
#     0,
#     59.9265102,
#     23,
#     79.25984015,
#     63.69863213,
#     69.03633491,
#     78.513461,
#     25.87509155,
#     24.64704465]},
#   {'s': 'LSE:QQ.',
#    'd': ['QINETIQ GROUP ORD GBP0.01',
#     0.27272727,
#     56.94472537,
#     6.39999,
#     10.06663944,
#     23.76018431,
#     53.48454503,
#     59.27293373,
#     3.23065311,
#     2.76946431]},
#   {'s': 'LSE:CWK',
#    'd': ['CRANSWICK ORD GBP0.10',
#     0.09090909,
#     53.47173671,
#     52,
#     71.25102647,
#     43.37700146,
#     48.33333333,
#     57.51246439,
#     22.52585793,
#     18.1187983]},
#   {'s': 'LSE:WIZZ',
#    'd': ['WIZZ AIR HLDGS PLC ORD GBP0.0001',
#     0.09090909,
#     57.85020385,
#     214,
#     24.71148971,
#     118.18812917,
#     78.32715286,
#     77.70173516,
#     -18.96409802,
#     -63.47428496]},
#   {'s': 'LSE:ONT',
#    'd': ['OXFORD NANOPORE TECHNOLOGIES PLC ORD GBP0.0001',
#     0.09090909,
#     51.78545683,
#     9.8,
#     7.13676059,
#     35.18995161,
#     60.79842066,
#     64.79711295,
#     1.15231461,
#     -0.33492092]},
#   {'s': 'LSE:GRI',
#    'd': ['GRAINGER PLC ORD GBP0.05',
#     0.18181818,
#     60.72119021,
#     27.33,
#     13.92765618,
#     91.1181566,
#     74.51937027,
#     82.39023359,
#     3.66615271,
#     0.76490736]},
#   {'s': 'LSE:HBR',
#    'd': ['HARBOUR ENERGY PLC ORD GBP0.00002',
#     0.09090909,
#     31.55203397,
#     -26.3674,
#     -11.39322609,
#     -241.34152757,
#     1.13730965,
#     6.82344355,
#     -4.98390675,
#     -1.61755698]},
#   {'s': 'LSE:AML',
#    'd': ['ASTON MARTIN LAGONDA GBL HLDGS PLC ORD GBP0.1',
#     0.18181818,
#     36.82119034,
#     -5.39999,
#     -30.34023909,
#     -66.56560856,
#     46.27127315,
#     45.31942981,
#     -16.27938064,
#     -18.35057062]},
#   {'s': 'LSE:PHLL',
#    'd': ['PETERSHILL PARTNERS PLC ORD USD0.01',
#     0.09090909,
#     48.87895344,
#     2.39999,
#     2.68059959,
#     13.23238645,
#     44.33960692,
#     50.97262786,
#     -0.66685177,
#     -1.21228108]},
#   {'s': 'LSE:BBY',
#    'd': ['BALFOUR BEATTY GBP0.50',
#     0.09090909,
#     48.89354368,
#     10.60001,
#     1.50012929,
#     23.74138237,
#     53.25670685,
#     67.70254848,
#     -1.27343733,
#     -2.80198933]},
#   {'s': 'LSE:DRX',
#    'd': ['DRAX GROUP PLC ORD GBP0.1155172',
#     0.18181818,
#     46.1444824,
#     -5.2,
#     4.81457035,
#     24.43431281,
#     62.79071059,
#     65.80534668,
#     -5.9872149,
#     -9.78147026]},
#   {'s': 'LSE:ITH',
#    'd': ['ITHACA ENERGY PLC ORD GBP0.01',
#     -0.09090909,
#     40.12456232,
#     -3.19999,
#     -3.99691735,
#     -166.79216908,
#     20.46159852,
#     31.34474592,
#     -1.3089492,
#     -0.34866832]},
#   {'s': 'LSE:RDW',
#    'd': ['REDROW PLC ORD GBP0.105',
#     0,
#     60.25255755,
#     35.70001,
#     17.73347871,
#     107.91513327,
#     73.95832963,
#     77.29902874,
#     5.45159181,
#     1.86826931]},
#   {'s': 'LSE:BGEO',
#    'd': ['BANK OF GEORGIA GROUP PLC ORD GBP0.01',
#     0.09090909,
#     59.61337704,
#     306.995,
#     11.39300618,
#     102.2985565,
#     85.88738596,
#     86.1251042,
#     -0.0163741,
#     -32.51693357]},
#   {'s': 'LSE:SRP',
#    'd': ['SERCO GROUP GBP0.02',
#     0.27272727,
#     54.256378,
#     5.3,
#     1.40883862,
#     48.71330226,
#     63.93939394,
#     68.64647576,
#     -0.14013873,
#     -0.74740497]},
#   {'s': 'LSE:TPK',
#    'd': ['TRAVIS PERKINS PLC ORD 1205105',
#     0,
#     43.18542165,
#     19.128,
#     -14.59727365,
#     -22.84276622,
#     47.26228603,
#     61.18088599,
#     -11.02075363,
#     -15.80494994]},
#   {'s': 'LSE:HAS',
#    'd': ['HAYS PLC ORD GBP0.01',
#     0.18181818,
#     53.70211377,
#     7.600002,
#     -1.81109079,
#     75.91300354,
#     71.38365275,
#     73.32696088,
#     -0.85828132,
#     -1.77662646]},
#   {'s': 'LSE:SMWH',
#    'd': ['WH SMITH PLC ORD GBP0.220895',
#     0.18181818,
#     41.12935012,
#     -12,
#     -60.33085294,
#     -56.5331851,
#     43.33350787,
#     42.08763142,
#     -32.20792121,
#     -37.8127543]},
#   {'s': 'LSE:ENOG',
#    'd': ['ENERGEAN PLC ORD GBP0.01',
#     0.09090909,
#     40.9639235,
#     48.5,
#     -64.56573485,
#     1.77321633,
#     49.68537905,
#     55.68115683,
#     -36.962504,
#     -49.15467751]},
#   {'s': 'LSE:TBCG',
#    'd': ['TBC BANK GROUP PLC ORD GBP0.01',
#     0.09090909,
#     48.9324455,
#     137.585,
#     -39.63607941,
#     10.03142635,
#     72.25778867,
#     74.04054103,
#     -18.61787386,
#     -30.60655813]},
#   {'s': 'LSE:SSPG',
#    'd': ['SSP GROUP PLC ORD GBP0.01085',
#     0.18181818,
#     45.32760724,
#     8.99999,
#     -3.20376115,
#     30.46355905,
#     62.65303247,
#     64.33722635,
#     -4.50733034,
#     -6.66444526]},
#   {'s': 'LSE:BPT',
#    'd': ['BRIDGEPOINT GROUP PLC ORD GBP0.00005',
#     0,
#     56.7335021,
#     12.60001,
#     4.95968297,
#     56.04823106,
#     75.51722989,
#     80.87105589,
#     1.42309072,
#     -0.17444435]},
#   {'s': 'LSE:DOM',
#    'd': ["DOMINO'S PIZZA GROUP PLC ORD GBP0.00520833",
#     0.18181818,
#     60.0381532,
#     27.4,
#     1.83151518,
#     103.85751473,
#     90.25392417,
#     87.45225246,
#     -1.10472373,
#     -4.88083401]},
#   {'s': 'LSE:DWL',
#    'd': ['DOWLAIS GROUP PLC ORD GBP0.01',
#     0.09090909,
#     53.22920302,
#     15.229999,
#     4.56181007,
#     84.81091821,
#     85.55868602,
#     91.11651622,
#     0.0876391,
#     -1.82227351]},
#   {'s': 'LSE:KNOS',
#    'd': ['KAINOS GROUP PLC ORD GBP0.005',
#     -0.09090909,
#     59.6780684,
#     77.0105,
#     26.51220441,
#     135.35858534,
#     81.64504831,
#     80.58305362,
#     4.09843625,
#     -8.61588435]},
#   {'s': 'LSE:LRE',
#    'd': ['LANCASHIRE HLDGS COM SHS USD0.50',
#     -0.09090909,
#     64.47811256,
#     48.5,
#     20.33602926,
#     152.90066074,
#     92.24848068,
#     88.44041506,
#     5.88419267,
#     0.16291238]},
#   {'s': 'LSE:MONY',
#    'd': ['MONEYSUPERMARKET.COM GROUP PLC ORD GBP0.0002',
#     0.18181818,
#     66.97933858,
#     12.80001,
#     15.94323024,
#     124.58680005,
#     80.93089235,
#     79.36564469,
#     5.70916712,
#     4.82607361]},
#   {'s': 'LSE:GNS',
#    'd': ['GENUS ORD GBP0.10',
#     0.18181818,
#     50.61760755,
#     7.348,
#     76.31213529,
#     -48.47172886,
#     47.4490991,
#     61.68723724,
#     11.31647321,
#     10.17391906]},
#   {'s': 'LSE:WOSG',
#    'd': ['WATCHES OF SWITZERLAND GROUP PLC ORD GBP0.0125',
#     0,
#     64.0194433,
#     81.20001,
#     25.26669221,
#     269.86177963,
#     78.36940185,
#     76.4108437,
#     3.46357209,
#     -8.65970725]},
#   {'s': 'LSE:IWG',
#    'd': ['IWG PLC ORD GBP0.01',
#     0,
#     50.33078148,
#     10.9,
#     1.38557488,
#     87.73525692,
#     74.9115432,
#     80.38779478,
#     -1.83357931,
#     -3.72240456]},
#   {'s': 'LSE:PETS',
#    'd': ['PETS AT HOME GROUP PLC ORD GBP0.01',
#     0.18181818,
#     42.27063469,
#     12.39999,
#     -17.92799168,
#     -18.41847509,
#     44.93567845,
#     43.33193508,
#     -9.77607274,
#     -12.08564219]},
#   {'s': 'LSE:TRN',
#    'd': ['TRAINLINE PLC ORD GBP0.01',
#     0.18181818,
#     67.0170586,
#     50.8,
#     21.11535406,
#     136.49082391,
#     81.41592429,
#     78.89216814,
#     7.32219714,
#     2.71413955]},
#   {'s': 'LSE:HILS',
#    'd': ['HILL & SMITH PLC ORD GBP0.25',
#     0,
#     53.31020746,
#     50,
#     26.32454882,
#     84.56323813,
#     76.19047619,
#     80.3580922,
#     1.57661671,
#     -6.89775924]},
#   {'s': 'LSE:DATA',
#    'd': ['GLOBALDATA PLC ORD GBP0.0001',
#     -0.45454545,
#     59.67433344,
#     12.5,
#     8.53881956,
#     142.69350073,
#     91.39089408,
#     91.83263199,
#     -0.82603043,
#     -4.42998957]},
#   {'s': 'LSE:MTO',
#    'd': ['MITIE GROUP ORD GBP0.025',
#     0.18181818,
#     57.60067253,
#     5.699997,
#     1.27503701,
#     70.89026327,
#     75.4601227,
#     74.01615404,
#     0.31515359,
#     -0.1992914]},
#   {'s': 'LSE:RAT',
#    'd': ['RATHBONES GROUP PLC ORD GBP0.05',
#     -0.09090909,
#     45.26765803,
#     56.02,
#     -46.4815,
#     -2.53710549,
#     57.87912088,
#     62.48563717,
#     -27.10318507,
#     -39.84561365]},
#   {'s': 'LSE:OSB',
#    'd': ['OSB GROUP PLC ORD GBP0.01',
#     0.09090909,
#     59.44928436,
#     55.40001,
#     24.45143774,
#     117.85239581,
#     72.97734223,
#     80.25465448,
#     5.19554154,
#     -1.18614217]},
#   {'s': 'LSE:MAB',
#    'd': ['MITCHELLS & BUTLERS PLC ORD GBP0.085416',
#     0.09090909,
#     60.88490336,
#     19.7964,
#     9.44701691,
#     143.02500914,
#     76.48975631,
#     80.87278533,
#     2.14452755,
#     -0.26591345]},
#   {'s': 'LSE:TCAP',
#    'd': ['TP ICAP GROUP PLC ORD GBP0.25',
#     0.27272727,
#     55.57611275,
#     3.3,
#     1.84107515,
#     75.82327994,
#     68.10962419,
#     66.1856231,
#     0.66684858,
#     0.371199]},
#   {'s': 'LSE:PAGE',
#    'd': ['PAGEGROUP PLC ORD GBP0.01',
#     0.18181818,
#     60.00734544,
#     46.6,
#     2.28024879,
#     99.37534625,
#     83.25523476,
#     83.31248308,
#     -1.31309699,
#     -6.0807214]},
#   {'s': 'LSE:VCT',
#    'd': ['VICTREX ORD GBP0.01',
#     0,
#     65.55191838,
#     137,
#     72.27543676,
#     128.22216777,
#     85.41666667,
#     90.10296271,
#     16.99226313,
#     0.47987707]},
#   {'s': 'LSE:TEP',
#    'd': ['TELECOM PLUS ORD GBP0.05',
#     0.18181818,
#     56.62661121,
#     114.497,
#     97.44079794,
#     74.92867673,
#     75.13963585,
#     83.70747289,
#     23.16219342,
#     10.44721723]},
#   {'s': 'LSE:RHIM',
#    'd': ['RHI MAGNESITA N.V. ORD EUR1.00 (DI)',
#     0.09090909,
#     49.29515593,
#     108,
#     -39.85130118,
#     7.67376222,
#     77.11442786,
#     76.51136128,
#     -30.65410235,
#     -48.34059338]},
#   {'s': 'LSE:FOUR',
#    'd': ['4IMPRINT GROUP ORD 38 6/13P',
#     -0.18181818,
#     32.44476098,
#     -400,
#     35.77757353,
#     -106.16766692,
#     41.01382488,
#     63.18484383,
#     -53.14244797,
#     -24.49724049]},
#   {'s': 'LSE:PTEC',
#    'd': ['PLAYTECH PLC ORD NPV',
#     0.18181818,
#     48.91244227,
#     40.8,
#     2.37970353,
#     88.00284625,
#     73.09238454,
#     79.1496082,
#     -6.73072649,
#     -14.09340246]},
#   {'s': 'LSE:BYIT',
#    'd': ['BYTES TECHNOLOGY GROUP PLC ORD GBP0.01',
#     0.09090909,
#     56.64646633,
#     21.70001,
#     11.02467979,
#     56.95574648,
#     78.26086619,
#     79.38232944,
#     4.08122394,
#     1.59048947]},
#   {'s': 'LSE:ASCL',
#    'd': ['ASCENTIAL PLC ORD GBP0.01',
#     0.18181818,
#     75.4477206,
#     57.2,
#     44.65410982,
#     81.67176318,
#     69.23657974,
#     70.37036911,
#     16.33706769,
#     12.40351264]},
#   {'s': 'LSE:NBS',
#    'd': ['NATIONWIDE BUILDING SOCIETY CORE CAPITAL DEFERRED GBP1',
#     0,
#     38.0716302,
#     -0.5,
#     -1.87352941,
#     -98.7654321,
#     61.11111111,
#     61.11111111,
#     -0.51091172,
#     -0.60570546]},
#   {'s': 'LSE:DOCS',
#    'd': ['DR. MARTENS PLC ORD GBP0.01',
#     0.18181818,
#     49.2553499,
#     8.3,
#     -5.06626647,
#     80.75481118,
#     61.89838951,
#     62.61717162,
#     -3.42552788,
#     -5.12008107]},
#   {'s': 'LSE:CBG',
#    'd': ['CLOSE BROS GROUP ORD GBP0.25',
#     0.09090909,
#     43.03224289,
#     39,
#     -32.27061397,
#     -48.70355922,
#     47.41222672,
#     53.57985006,
#     -14.24483494,
#     -16.46324596]},
#   {'s': 'LSE:QLT',
#    'd': ['QUILTER PLC ORD GBP0.08167',
#     0.09090909,
#     61.87032522,
#     9.599997,
#     3.1270392,
#     88.64580361,
#     83.22513199,
#     87.31579193,
#     0.7573561,
#     -0.40387829]},
#   {'s': 'LSE:SVS',
#    'd': ['SAVILLS ORD GBP0.025',
#     0.18181818,
#     50.56923914,
#     48,
#     -3.08279412,
#     64.86465621,
#     74.68123862,
#     81.77819019,
#     -7.35239464,
#     -15.70002245]},
#   {'s': 'LSE:AJB',
#    'd': ['AJ BELL PLC ORD GBP0.000125',
#     0.09090909,
#     52.21633743,
#     8.60001,
#     3.27155276,
#     58.12667578,
#     67.52136076,
#     70.78467697,
#     -0.63177083,
#     -3.17373533]},
#   {'s': 'LSE:PLUS',
#    'd': ['PLUS500 LIMITED ORD ILS0.01 (DI)',
#     0.09090909,
#     52.36769244,
#     -17,
#     51.85669265,
#     38.39527196,
#     58.71559633,
#     63.1978966,
#     12.85245696,
#     9.14598541]},
#   {'s': 'LSE:BOY',
#    'd': ['BODYCOTE PLC ORD GBP0.1727272',
#     0.09090909,
#     43.9534137,
#     28.699,
#     -20.53215691,
#     -11.94522593,
#     63.76620865,
#     63.17682435,
#     -11.84445772,
#     -16.52723651]},
#   {'s': 'LSE:OXIG',
#    'd': ['OXFORD INSTRUMENTS ORD GBP0.05',
#     0.09090909,
#     50.08443304,
#     137.36,
#     -69.89852412,
#     54.92854998,
#     82.2106944,
#     76.61024132,
#     -43.03979977,
#     -70.07712758]},
#   {'s': 'LSE:JTC',
#    'd': ['JTC PLC ORD GBP0.01',
#     0,
#     47.7104243,
#     31.5,
#     0.21984474,
#     5.51878251,
#     53.42465753,
#     67.68138001,
#     -4.49060316,
#     -9.95457696]},
#   {'s': 'LSE:COA',
#    'd': ['COATS GROUP PLC ORD GBP0.05',
#     -0.09090909,
#     46.97165108,
#     -0.100003,
#     -1.30533489,
#     -15.19310133,
#     59.09092195,
#     64.76166869,
#     -0.72138169,
#     -1.01719514]},
#   {'s': 'LSE:VSVS',
#    'd': ['VESUVIUS PLC ORD GBP0.10',
#     0.09090909,
#     48.13845333,
#     11.40001,
#     -0.96722838,
#     12.80569762,
#     52.68299399,
#     63.69469987,
#     -2.49306412,
#     -4.28252165]},
#   {'s': 'LSE:ASHM',
#    'd': ['ASHMORE GROUP ORD GBP0.0001',
#     0.18181818,
#     40.88996332,
#     1.35,
#     -9.55755556,
#     -53.28774866,
#     48.20626308,
#     58.8612008,
#     -4.05113932,
#     -4.69937897]},
#   {'s': 'LSE:BREE',
#    'd': ['BREEDON GRP PLC ORD GBP0.01',
#     0.09090909,
#     46.98868559,
#     15,
#     -2.70631456,
#     7.91165352,
#     57.4247277,
#     63.13604471,
#     -3.19742491,
#     -5.22010568]},
#   {'s': 'LSE:YOU',
#    'd': ['YOUGOV ORD GBP0.002',
#     0.18181818,
#     61.33346811,
#     38,
#     49.16470647,
#     157.51792108,
#     82.66666667,
#     59.55555556,
#     18.52729814,
#     13.87596138]},
#   {'s': 'LSE:FUTR',
#    'd': ['FUTURE PLC ORD GBP0.15',
#     0.18181818,
#     60.08551491,
#     80.5,
#     69.59347459,
#     79.77665441,
#     70.49490539,
#     77.30831215,
#     25.88355931,
#     22.3019099]},
#   {'s': 'LSE:PFD',
#    'd': ['PREMIER FOODS ORD GBP0.10',
#     -0.18181818,
#     64.94408007,
#     6.2,
#     3.02563147,
#     145.14095715,
#     82.80002646,
#     82.12544779,
#     1.08942972,
#     0.1419449]},
#   {'s': 'LSE:FGP',
#    'd': ['FIRSTGROUP ORD GBP0.05',
#     0.09090909,
#     60.27945306,
#     12.50001,
#     8.54119371,
#     55.29403057,
#     78.87518152,
#     84.54506273,
#     2.82510312,
#     1.83879784]},
#   {'s': 'LSE:WG.',
#    'd': ['JOHN WOOD GROUP PLC ORD GBP0.0428571',
#     -0.09090909,
#     56.14780153,
#     9.1,
#     3.20765597,
#     85.53876054,
#     82.89470048,
#     88.34731139,
#     0.30778445,
#     -1.47630737]},
#   {'s': 'LSE:BCG',
#    'd': ['BALTIC CLASSIFIEDS GROUP PLC ORD GBP0.01',
#     0,
#     62.69424991,
#     14,
#     9.14070559,
#     114.53145584,
#     64.38172043,
#     62.00404268,
#     2.83691119,
#     1.35740225]},
#   {'s': 'LSE:SRE',
#    'd': ['SIRIUS REAL ESTATE ORD NPV',
#     0.09090909,
#     61.72552562,
#     8.150003,
#     1.82247215,
#     106.76607184,
#     80.06230096,
#     82.35266439,
#     0.30933053,
#     -0.58421374]},
#   {'s': 'LSE:CEY',
#    'd': ['CENTAMIN PLC ORD NPV (DI)',
#     -0.09090909,
#     54.08806355,
#     5.475002,
#     2.06889854,
#     57.61646032,
#     73.11711964,
#     69.62236737,
#     0.29408809,
#     -0.358077]},
#   {'s': 'LSE:PAG',
#    'd': ['PARAGON BANKING GROUP PLC ORD GBP1',
#     0.18181818,
#     39.79751004,
#     -4.84039,
#     -17.64570056,
#     -89.07928784,
#     30.97824881,
#     32.29939343,
#     -9.65502854,
#     -10.25933012]},
#   {'s': 'LSE:THG',
#    'd': ['THG PLC ORD GBP0.005',
#     0.09090909,
#     50.59388744,
#     6.899999,
#     2.23565383,
#     68.74883263,
#     70.5943198,
#     75.68801286,
#     -0.54373442,
#     -1.57814312]},
#   {'s': 'LSE:MGNS',
#    'd': ['MORGAN SINDALL GRP ORD GBP0.05',
#     0.18181818,
#     49.98780043,
#     78,
#     -7.66948824,
#     21.82778936,
#     53.86313466,
#     61.3314148,
#     -10.37284193,
#     -17.7091036]},
#   {'s': 'LSE:SPI',
#    'd': ['SPIRE HEALTHCARE GROUP PLC ORD GBP0.01',
#     -0.09090909,
#     56.49880778,
#     7.61,
#     1.96670603,
#     113.86654551,
#     78.82051282,
#     83.3157262,
#     0.63680364,
#     -0.56398324]},
#   {'s': 'LSE:JDW',
#    'd': ['WETHERSPOON(J.D.) ORD GBP0.02',
#     0.18181818,
#     61.47547901,
#     64.375,
#     15.1110315,
#     127.3762447,
#     84.34588172,
#     84.96514839,
#     2.51020888,
#     -5.91377059]},
#   {'s': 'LSE:CKN',
#    'd': ['CLARKSON ORD GBP0.25',
#     0.18181818,
#     54.83640693,
#     145,
#     46.93198382,
#     71.75153603,
#     68.42105263,
#     75.97925632,
#     7.2870187,
#     -9.79692062]},
#   {'s': 'LSE:CHG',
#    'd': ['CHEMRING GROUP ORD GBP0.01',
#     0,
#     57.49139662,
#     10.5,
#     11.06918806,
#     82.66818162,
#     61.82795699,
#     65.95525144,
#     3.01090228,
#     1.61129626]},
#   {'s': 'LSE:JUST',
#    'd': ['JUST GROUP PLC ORD GBP0.10',
#     0,
#     57.32775501,
#     3.9,
#     4.22630052,
#     61.27969589,
#     69.36790628,
#     72.02618951,
#     1.04284158,
#     0.68180126]},
#   {'s': 'LSE:REDD',
#    'd': ['REDDE NORTHGATE PLC ORD GBP0.50',
#     0.18181818,
#     60.7781564,
#     27,
#     17.34982144,
#     88.79302549,
#     65.52199697,
#     74.71229299,
#     5.03095256,
#     2.33588397]},
#   {'s': 'LSE:IHP',
#    'd': ['INTEGRAFIN HOLDINGS PLC ORD GBP0.01',
#     0,
#     56.63559039,
#     16.80001,
#     6.03368256,
#     94.3206435,
#     71.02507181,
#     76.99133076,
#     0.45460293,
#     -2.13309089]},
#   {'s': 'LSE:FAN',
#    'd': ['VOLUTION GRP PLC ORD GBP0.01',
#     0.18181818,
#     64.52112833,
#     45.19999,
#     18.23220865,
#     103.79291841,
#     90.72849184,
#     89.34513376,
#     6.03427471,
#     1.77152752]},
#   {'s': 'LSE:AWE',
#    'd': ['ALPHAWAVE IP GROUP PLC ORD GBP0.01',
#     0.09090909,
#     40.99243329,
#     6.080003,
#     -5.30209418,
#     11.9681194,
#     67.96717465,
#     62.91562207,
#     -4.71298144,
#     -6.46952941]},
#   {'s': 'LSE:SEPL',
#    'd': ['SEPLAT ENERGY PLC NGN0.5 (DI)',
#     0,
#     49.93137845,
#     -0.2,
#     2.66211132,
#     -27.88187122,
#     63.15789474,
#     71.05261696,
#     0.73321475,
#     0.66121546]},
#   {'s': 'LSE:ALPH',
#    'd': ['ALPHA GROUP INTERNATIONAL PLC ORD GBP0.002',
#     0.09090909,
#     46.8169607,
#     62,
#     -134.84338559,
#     18.81255888,
#     63.5736292,
#     50.59491584,
#     -65.33270442,
#     -83.06487787]},
#   {'s': 'LSE:ATG',
#    'd': ['AUCTION TECHNOLOGY GROUP PLC ORD GBP0.0001',
#     -0.09090909,
#     45.92414587,
#     13,
#     -5.83004382,
#     59.35892595,
#     65.73295985,
#     74.43017879,
#     -9.39957018,
#     -16.35073886]},
#   {'s': 'LSE:CRE',
#    'd': ['CONDUIT HLDGS LTD COM SHS USD0.01 (DI)',
#     0.18181818,
#     53.49056972,
#     10.661,
#     -8.18394574,
#     60.08143893,
#     32.53587819,
#     28.78630395,
#     -3.71401008,
#     -4.51453592]},
#   {'s': 'LSE:ELM',
#    'd': ['ELEMENTIS ORD GBP0.05',
#     0.18181818,
#     58.40538727,
#     11.8,
#     5.06679353,
#     78.26641907,
#     71.34758982,
#     77.68047574,
#     1.54135282,
#     0.34462666]},
#   {'s': 'LSE:HTWS',
#    'd': ['HELIOS TOWERS PLC ORD GBP0.01',
#     -0.09090909,
#     45.76447358,
#     4.149998,
#     -3.05105557,
#     24.15437429,
#     61.19272837,
#     57.39940671,
#     -2.47239759,
#     -3.60239663]},
#   {'s': 'LSE:TIFS',
#    'd': ['TI FLUID SYSTEMS PLC ORD GBP0.01',
#     -0.09090909,
#     64.6603139,
#     15.2,
#     9.43165209,
#     125.55979001,
#     85.39943526,
#     87.70226101,
#     2.4568319,
#     0.79968605]},
#   {'s': 'LSE:GEN',
#    'd': ['GENUIT GROUP PLC ORD GBP0.001',
#     0.09090909,
#     41.68742964,
#     11.25,
#     -15.07905265,
#     -21.25662633,
#     64.78494624,
#     72.17293907,
#     -7.29329703,
#     -9.43088717]},
#   {'s': 'LSE:SEIT',
#    'd': ['SDCL ENERGY EFFICIENCY INC TST PLC ORD GBP0.01',
#     0.09090909,
#     46.57005782,
#     4.062298,
#     -0.99812937,
#     72.33107399,
#     75.99647552,
#     83.20252878,
#     -1.14183405,
#     -2.01085907]},
#   {'s': 'LSE:DEC',
#    'd': ['DIVERSIFIED ENERGY COMPANY PLC ORD GBP0.01',
#     0.18181818,
#     38.60464879,
#     -0.761003,
#     -3.62299886,
#     -102.35420972,
#     39.3238877,
#     49.66499463,
#     -2.34638184,
#     -2.7289535]},
#   {'s': 'LSE:MGAM',
#    'd': ['MORGAN ADVANCED MATERIALS PLC ORD GBP0.25',
#     0.18181818,
#     49.48695192,
#     7.75,
#     -4.79918368,
#     7.54734244,
#     62.06587898,
#     61.17145734,
#     -2.97317999,
#     -4.52687729]},
#   {'s': 'LSE:SNR',
#    'd': ['SENIOR GBP0.10',
#     0.18181818,
#     45.27141348,
#     2,
#     -1.88172571,
#     -32.92605587,
#     38.13852355,
#     37.11559461,
#     -1.70285555,
#     -2.0423198]},
#   {'s': 'LSE:WPS',
#    'd': ['W.A.G PAYMENT SOLUTIONS PLC ORD GBP0.01',
#     0,
#     50.78025705,
#     0.8,
#     -1.73551198,
#     -44.44939911,
#     65.15152703,
#     60.60607404,
#     -0.38288961,
#     -0.20661561]},
#   {'s': 'LSE:0RQY',
#    'd': ['B.F. SPA NPV',
#     0.27272727,
#     66.93398733,
#     1.16,
#     0.70311765,
#     107.23404255,
#     84.91984522,
#     81.73620285,
#     0.26643581,
#     0.19351558]},
#   {'s': 'LSE:DSCV',
#    'd': ['DISCOVERIE GROUP PLC ORD GBP0.05',
#     0.09090909,
#     55.24840848,
#     44.1515,
#     -1.97191291,
#     105.30746708,
#     89.16034564,
#     85.88173138,
#     -5.3229309,
#     -13.10444677]},
#   {'s': 'LSE:HFG',
#    'd': ['HILTON FOOD GROUP PLC ORD GBP0.10',
#     0.18181818,
#     57.06919305,
#     36.997,
#     -15.63614926,
#     178.82276625,
#     58.59142699,
#     43.69677108,
#     -5.80382952,
#     -10.81582608]},
#   {'s': 'LSE:MOON',
#    'd': ['MOONPIG GROUP PLC ORD GBP0.1',
#     0.09090909,
#     65.80571857,
#     16.6,
#     6.74171635,
#     162.23660788,
#     93.22792211,
#     87.19934452,
#     2.27869474,
#     0.17143556]},
#   {'s': 'LSE:KLR',
#    'd': ['KELLER GROUP ORD GBP0.10',
#     0.18181818,
#     61.56517144,
#     43.2,
#     57.5996015,
#     110.12380321,
#     74.49570267,
#     81.1285672,
#     16.88105068,
#     8.89846797]},
#   {'s': 'LSE:CRW',
#    'd': ['CRANEWARE PLC ORD GBP0.01',
#     -0.09090909,
#     65.39919427,
#     60,
#     94.48292709,
#     111.9688762,
#     78.09693621,
#     79.52770468,
#     35.60882077,
#     29.73325959]},
#   {'s': 'LSE:BAG',
#    'd': ['BARR(A.G.) ORD GBP0.04167',
#     0.18181818,
#     58.88720531,
#     -1,
#     7.39926471,
#     75.0965818,
#     72.5,
#     73.33333333,
#     3.72159088,
#     2.99958887]},
#   {'s': 'LSE:SPT',
#    'd': ['SPIRENT COMMUNICATIONS ORD GBP0.03333',
#     0.18181818,
#     44.05326132,
#     5.700002,
#     -7.47272514,
#     62.29316479,
#     69.06343729,
#     74.63120834,
#     -4.86165531,
#     -7.04578055]},
#   {'s': 'LSE:PZC',
#    'd': ['PZ CUSSONS ORD GBP0.01',
#     0.18181818,
#     43.41834482,
#     3.2,
#     -5.13212412,
#     -5.23228762,
#     57.99455497,
#     52.47418024,
#     -3.27072823,
#     -4.26770505]},
#   {'s': 'LSE:MSLH',
#    'd': ['MARSHALLS ORD GBP0.25',
#     -0.18181818,
#     45.88847806,
#     11.99999,
#     -7.77753515,
#     79.73669244,
#     82.18623482,
#     83.17589744,
#     -5.52903347,
#     -8.6401775]},
#   {'s': 'LSE:JDG',
#    'd': ['JUDGES SCIENTIFIC ORD GBP0.05',
#     0.09090909,
#     45.69565966,
#     87.2,
#     -5.99207059,
#     46.08400852,
#     56.69174794,
#     72.17639951,
#     -53.37644427,
#     -107.03284864]},
#   {'s': 'LSE:MEGP',
#    'd': ['ME GROUP INTERNATIONAL PLC ORD GBP0.005',
#     0.18181818,
#     45.84782897,
#     0.566,
#     -3.903912,
#     -49.98021693,
#     47.52618512,
#     56.02132243,
#     -2.24726549,
#     -2.82578098]},
#   {'s': 'LSE:DAR',
#    'd': ['DAR GLOBAL PLC ORD USD0.01',
#     0,
#     43.54290801,
#     -0.01,
#     -0.02016176,
#     -12.91079812,
#     44.44444444,
#     42.59259259,
#     -0.00506044,
#     -0.00305881]},
#   {'s': 'LSE:ADT1',
#    'd': ['ADRIATIC METALS PLC ORD GBP0.013355',
#     0,
#     44.09811593,
#     1.80001,
#     0.00499488,
#     -21.59223257,
#     70.9076218,
#     76.694921,
#     -0.75964985,
#     -1.2881529]},
#   {'s': 'LSE:HOC',
#    'd': ['HOCHSCHILD MINING PLC ORD GBP0.01',
#     0.09090909,
#     72.79248323,
#     18.52,
#     15.99887689,
#     134.13926892,
# ...
#     -0.29937859]},
#   {'s': 'LSE:MBO',
#    'd': ['MOBILITYONE LTD ORD GBP0.025',
#     0.18181818,
#     51.52127954,
#     0.25,
#     -0.43547794,
#     37.48467332,
#     33.33333333,
#     27.77777778,
#     -0.11453313,
#     -0.13396265]},
#   {'s': 'LSE:JAN',
#    'd': ['JANGADA MINES PLC ORD GBP0.0004',
#     -0.09090909,
#     34.49189924,
#     0.0075,
#     -0.00762676,
#     -42.53716808,
#     51.17449664,
#     61.80089485,
#     -0.0196342,
#     -0.02826511]},
#   {'s': 'LSE:SCHO',
#    'd': ['SCHOLIUM GROUP PLC ORD GBP0.01',
#     0.09090909,
#     48.91568847,
#     0,
#     0.2882354,
#     165.53280115,
#     92.18750244,
#     97.39583415,
#     -0.00787249,
#     -0.01198962]},
#   {'s': 'LSE:HELD',
#    'd': ['HELLENIC DYNAMICS PLC ORD GBP0.001',
#     0,
#     22.46111509,
#     -0.0294,
#     -0.02971838,
#     -82.48007078,
#     14.4,
#     14.1974359,
#     -0.01230181,
#     -0.01101457]},
#   {'s': 'LSE:GILD',
#    'd': ['GUILD ESPORTS PLC ORD GBP0.001',
#     -0.18181818,
#     79.76369225,
#     0.349,
#     0.17623235,
#     184.21260353,
#     78.32362488,
#     81.668678,
#     0.04974583,
#     0.00484013]},
#   {'s': 'LSE:EVG',
#    'd': ['EVGEN PHARMA PLC ORD GBP0.0025',
#     -0.18181818,
#     24.50431963,
#     -0.25,
#     -0.13886015,
#     -112.67934419,
#     26.66666667,
#     35.55555556,
#     -0.06720282,
#     -0.06545351]},
#   {'s': 'LSE:NWT',
#    'd': ['NEWMARK SECURITY ORD GBP0.05',
#     0.18181818,
#     56.76421149,
#     2,
#     0.48617933,
#     58.05024588,
#     77.56749173,
#     77.56749173,
#     -0.01706805,
#     -0.38514424]},
#   {'s': 'LSE:AYM',
#    'd': ['ANGLESEY MINING ORD GBP0.01',
#     -0.27272727,
#     20.99282376,
#     -0.125,
#     -0.12350441,
#     -165.401524,
#     36.80555556,
#     42.87037037,
#     -0.05995851,
#     -0.05780359]},
#   {'s': 'LSE:AFP',
#    'd': ['AFRICAN PIONEER PLC ORD NPV',
#     0,
#     40.24526088,
#     -0.275,
#     0.01911176,
#     -45.14684048,
#     61.39359699,
#     65.16007533,
#     -0.00554476,
#     -0.00857384]},
#   {'s': 'LSE:AIQ',
#    'd': ['AIQ LTD ORDS GBP0.01 (DI)',
#     0.18181818,
#     10.23199596,
#     0,
#     -0.17539265,
#     13.24503311,
#     61.53846154,
#     61.53846154,
#     -0.02088766,
#     -0.03063401]},
#   {'s': 'LSE:BIOM',
#    'd': ['BIOME TECHNOLOGIES ORD GBP0.05',
#     0.27272727,
#     15.40308155,
#     -2.5,
#     -10.39191162,
#     -105.77942457,
#     40.64749927,
#     45.32374963,
#     -5.15676504,
#     -5.63301034]},
#   {'s': 'LSE:GENF',
#    'd': ['GENFLOW BIOSCIENCES PLC ORD GBP0.0003',
#     -0.09090909,
#     40.0153389,
#     -0.013,
#     -0.03251618,
#     115.02802368,
#     76.78004535,
#     75.63346706,
#     -0.05671097,
#     -0.07805825]},
#   {'s': 'LSE:FINS',
#    'd': ['FINANCIALS ACQUISITION CORP ORD GBP0.0001 (DI)',
#     -0.09090909,
#     46.20792028,
#     -7.5,
#     -6.38235294,
#     -34.25559947,
#     84.21052632,
#     80.70175439,
#     -2.14822364,
#     -1.70652014]},
#   {'s': 'LSE:ENET',
#    'd': ['ETHERNITY NETWORKS LTD ORD ILS0.001 (DI)',
#     0,
#     60.86048694,
#     1.48,
#     1.95761618,
#     73.20019446,
#     64.81481481,
#     66,
#     0.59633598,
#     0.42830636]},
#   {'s': 'LSE:WEB',
#    'd': ['WEBIS HOLDINGS PLC ORD GBP0.01',
#     0,
#     18.22188613,
#     -0.15,
#     -0.19663824,
#     -53.02994761,
#     33.33333333,
#     33.14859552,
#     -0.08446336,
#     -0.07472001]},
#   {'s': 'LSE:BLU',
#    'd': ['BLUE STAR CAPITAL ORD GBP0.001',
#     0.18181818,
#     67.41590303,
#     0.0165,
#     -0.00400456,
#     228.10174988,
#     39.08642464,
#     26.72852944,
#     -0.00244858,
#     -0.00446377]},
#   {'s': 'LSE:BMV',
#    'd': ['BLUEBIRD MERCHANT VENTURES LTD ORD NPV (DI)',
#     0,
#     30.86096947,
#     -0.025,
#     -0.07995368,
#     -80.35233822,
#     33.33333333,
#     36.11111111,
#     -0.0398329,
#     -0.03920853]},
#   {'s': 'LSE:DBOX',
#    'd': ['DIGITALBOX PLC ORD GBP0.01',
#     0.27272727,
#     47.88526205,
#     0.0749,
#     0.18324765,
#     59.75716421,
#     49.33891109,
#     40.68146304,
#     -0.0805937,
#     -0.129931]},
#   {'s': 'LSE:COBR',
#    'd': ['COBRA RESOURCES PLC ORD GBP0.01',
#     0,
#     33.3299885,
#     -0.005,
#     -0.11250603,
#     -51.7577022,
#     56,
#     55.2183908,
#     -0.06064983,
#     -0.06967129]},
#   {'s': 'LSE:ADA',
#    'd': ['ADAMS PLC ORD GBP0.01',
#     0.18181818,
#     5.789e-05,
#     0,
#     -0.02088235,
#     44.44444444,
#     100,
#     100,
#     -0.0312278,
#     -0.04502298]},
#   {'s': 'LSE:BYOT',
#    'd': ['BYOTROL ORD GBP0.0025',
#     0.18181818,
#     24.62258875,
#     -0.1761,
#     -0.25714559,
#     -63.23447232,
#     35.8034188,
#     34.44159544,
#     -0.12569836,
#     -0.13579052]},
#   {'s': 'LSE:THR',
#    'd': ['THOR ENERGY PLC ORD GBP0.001',
#     -0.09090909,
#     34.2219229,
#     -0.03,
#     -0.09038662,
#     -62.07685159,
#     36.66666667,
#     42.77777778,
#     -0.05236903,
#     -0.06322088]},
#   {'s': 'LSE:MAFL',
#    'd': ['MINERAL & FINANCIAL INVESTMENTS LTD ORD GBP0.01 (DI)',
#     0.36363636,
#     49.88397403,
#     -0.4,
#     0.26753147,
#     29.08186005,
#     69.53594771,
#     73.88671024,
#     -0.02083336,
#     -0.13040987]},
#   {'s': 'LSE:PIP',
#    'd': ['PIPEHAWK ORD GBP0.01',
#     0.18181818,
#     73.37674044,
#     0,
#     0.35070294,
#     41.42222222,
#     100,
#     100,
#     0.10997128,
#     0.08717934]},
#   {'s': 'LSE:GTC',
#    'd': ['GETECH GROUP ORD GBP0.0025',
#     0.09090909,
#     16.51173902,
#     -0.65,
#     -0.89842882,
#     -95.59739383,
#     9.16256158,
#     9.59496442,
#     -0.42787106,
#     -0.43527787]},
#   {'s': 'LSE:RGO',
#    'd': ['RIVERFORT GLOBAL OPPORTUNITIES PLC ORD GBP0.0001',
#     -0.09090909,
#     0.16541174,
#     -0.025,
#     -0.02668235,
#     -150.17076163,
#     33.57406581,
#     40.72564439,
#     -0.01473176,
#     -0.01519757]},
#   {'s': 'LSE:STK',
#    'd': ['STREAKSAI PLC ORD GBP0.001',
#     -0.09090909,
#     6.57040724,
#     -0.15,
#     -0.14679574,
#     -181.30296886,
#     49.27536232,
#     54.10628019,
#     -0.12106231,
#     -0.13935262]},
#   {'s': 'LSE:MBT',
#    'd': ['MOBILE TORNADO GRP ORD GBP0.02',
#     0.18181818,
#     20.57963385,
#     0,
#     -0.15805147,
#     -36.54634404,
#     66.64234109,
#     54.69705441,
#     -0.07599714,
#     -0.08897134]},
#   {'s': 'LSE:XSG',
#    'd': ['XEROS TECHNOLOGY GROUP PLC ORD GBP0.001',
#     0.09090909,
#     69.06200277,
#     0.9,
#     0.03198662,
#     108.13347085,
#     90.90909091,
#     75.32828283,
#     -0.02142037,
#     -0.14309654]},
#   {'s': 'LSE:WCAT',
#    'd': ['WILDCAT PETROLEUM PLC ORD GBP0.000028',
#     0,
#     29.81010191,
#     -0.01708,
#     -0.08733847,
#     -41.23683514,
#     35.1884058,
#     34.9178744,
#     -0.04234789,
#     -0.04759144]},
#   {'s': 'LSE:NBB',
#    'd': ['NORMAN BROADBENT PLC ORD GBP0.01',
#     0,
#     94.71537347,
#     0,
#     0.29727941,
#     -46.34288631,
#     61.53846154,
#     60.25641026,
#     0.15136266,
#     0.17096166]},
#   {'s': 'LSE:BANK',
#    'd': ['FIINU PLC ORD GBP0.10',
#     -0.09090909,
#     65.11068988,
#     0.3,
#     -0.00597618,
#     174.03197238,
#     81.61769887,
#     68.17727049,
#     -0.04559472,
#     -0.10552004]},
#   {'s': 'LSE:MOS',
#    'd': ['MOBILE STREAMS ORD GBP0.0001',
#     -0.18181818,
#     34.79968526,
#     -0.0031,
#     -0.01326647,
#     -108.02204532,
#     50.78787879,
#     51.66610404,
#     -0.00363172,
#     -0.00293323]},
#   {'s': 'LSE:WSG',
#    'd': ['WESTMINSTER GROUP PLC ORD GBP0.001',
#     0,
#     43.10610482,
#     0,
#     -0.05189353,
#     31.96978743,
#     50.61728395,
#     52.78825066,
#     -0.03726248,
#     -0.05218574]},
#   {'s': 'LSE:FLK',
#    'd': ['FLETCHER KING ORD GBP0.10',
#     0.27272727,
#     66.97248876,
#     2,
#     -1.78308818,
#     -27.10989619,
#     62.96296296,
#     50.61728395,
#     -0.33881187,
#     -0.40062457]},
#   {'s': 'LSE:LOOP',
#    'd': ['LOOPUP GROUP PLC ORD GBP0.005',
#     -0.18181818,
#     31.85358037,
#     -0.05,
#     -0.24135441,
#     -65.10309956,
#     22.22222222,
#     21.99074074,
#     -0.09573273,
#     -0.0870638]},
#   {'s': 'LSE:PRIM',
#    'd': ['PRIMORUS INVESTMENTS PLC ORD GBP0.002',
#     0.18181818,
#     18.87361334,
#     0,
#     -0.19052647,
#     -37.82687915,
#     52.38095238,
#     47.83068783,
#     -0.07711411,
#     -0.07906874]},
#   {'s': 'LSE:JWNG',
#    'd': ['JAYWING PLC ORD GBP0.05',
#     0.09090909,
#     35.56560292,
#     0.2,
#     -0.13298382,
#     -33.50281375,
#     60.92613854,
#     62.80137773,
#     -0.09747299,
#     -0.111458]},
#   {'s': 'LSE:CNG',
#    'd': ['CHINA NONFERROUS GOLD LTD ORD USD0.0001 (DI)',
#     0,
#     47.29767611,
#     -0.07,
#     0.14274882,
#     -94.09269674,
#     35.85858586,
#     41.52637486,
#     0.03381261,
#     0.04876685]},
#   {'s': 'LSE:LIB',
#    'd': ['LIBERTINE HOLDINGS PLC ORD GBP0.001',
#     0.18181818,
#     33.61598406,
#     0,
#     -0.05594853,
#     -46.50373388,
#     28.84615385,
#     28.84615385,
#     -0.09155693,
#     -0.11768382]},
#   {'s': 'LSE:SENX',
#    'd': ['SERINUS ENERGY PLC ORD NPV',
#     0,
#     69.30444479,
#     0.3,
#     0.38550279,
#     161.77940011,
#     91.30434783,
#     87.19806763,
#     0.14492059,
#     0.1198673]},
#   {'s': 'LSE:CMH',
#    'd': ['CHAMBERLIN ORD GBP0.001',
#     0.18181818,
#     28.25610379,
#     0,
#     -0.09379412,
#     64.33566434,
#     55.55555556,
#     55.55555556,
#     -0.04388136,
#     -0.0566458]},
#   {'s': 'LSE:MAST',
#    'd': ['MAST ENERGY DEVELOPMENTS PLC ORD GBP0.001',
#     0.18181818,
#     57.67382455,
#     0.3235,
#     0.07089029,
#     84.77072328,
#     64.7037037,
#     53.04938272,
#     -0.00602353,
#     -0.0410063]},
#   {'s': 'LSE:PEG',
#    'd': ['PETARDS GROUP ORD GBP0.01',
#     -0.09090909,
#     39.21531364,
#     -0.245,
#     0.23880147,
#     -178.61151194,
#     41.66666667,
#     51.38888889,
#     0.00750516,
#     0.01213571]},
#   {'s': 'LSE:HAMA',
#    'd': ['HAMAK GOLD LTD ORD NPV (DI)',
#     -0.09090909,
#     0.01946239,
#     -0.35,
#     -0.59264706,
#     -92.7981782,
#     30,
#     26.66666667,
#     -0.23651907,
#     -0.22508883]},
#   {'s': 'LSE:PFP',
#    'd': ['PATHFINDER MINERALS ORD GBP0.001',
#     0,
#     14.26692749,
#     -0.09,
#     -0.05195603,
#     -137.25584838,
#     8.76369327,
#     4.38184664,
#     -0.02555147,
#     -0.01899092]},
#   {'s': 'LSE:RRR',
#    'd': ['RED ROCK RESOURCES ORD GBP0.0001',
#     0,
#     48.90808584,
#     -0.0039,
#     0.00257618,
#     -50.75445816,
#     24.22222222,
#     28.70899471,
#     0.00116002,
#     0.00199598]},
#   {'s': 'LSE:DGI',
#    'd': ['DG INNOVATE PLC ORD GBP0.0001',
#     0,
#     0.03715055,
#     0,
#     -0.00616279,
#     -58.93484726,
#     21.73913043,
#     21.15942029,
#     -0.00269353,
#     -0.00263358]},
#   {'s': 'LSE:KRS',
#    'd': ['KERAS RESOURCES PLC ORD GBP0.01',
#     0.09090909,
#     53.35243435,
#     0,
#     -0.02781176,
#     -63.40449348,
#     58.62946163,
#     58.87251138,
#     0.00387978,
#     0.00060932]},
#   {'s': 'LSE:BIDS',
#    'd': ['BIDSTACK GROUP PLC ORD GBP0.005',
#     -0.09090909,
#     35.3812073,
#     -0.009,
#     -0.06176176,
#     -24.80067671,
#     40.74074074,
#     40.61728395,
#     -0.04825436,
#     -0.06416475]},
#   {'s': 'LSE:AUK',
#    'd': ['AUKETT SWANKE GROUP PLC ORD GBP0.01',
#     0.27272727,
#     1.81234177,
#     -0.37,
#     -0.29786471,
#     -217.54814686,
#     9.18968377,
#     11.46299156,
#     -0.1185614,
#     -0.088038]},
#   {'s': 'LSE:ORR',
#    'd': ['ORIOLE RESOURCES PLC ORD GBP0.001',
#     0,
#     41.63743621,
#     -0.0045,
#     -0.00481353,
#     -106.2806518,
#     53.33333333,
#     62.22222222,
#     -0.00318092,
#     -0.00411679]},
#   {'s': 'LSE:ECR',
#    'd': ['ECR MINERALS ORD GBP0.00001',
#     0.18181818,
#     57.51694148,
#     0.035,
#     -0.02921485,
#     136.84965871,
#     39.58333333,
#     29.25925926,
#     -0.00920782,
#     -0.01339612]},
#   {'s': 'LSE:FAB',
#    'd': ['FUSION ANTIBODIES PLC ORD GBP0.04',
#     -0.27272727,
#     42.63463014,
#     -0.728,
#     -0.54975529,
#     -70.14460635,
#     17.74712644,
#     13.87696993,
#     -0.2121076,
#     -0.18398793]},
#   {'s': 'LSE:CLON',
#    'd': ['CLONTARF ENERGY ORD GBP0.0001',
#     -0.09090909,
#     48.12180086,
#     0.0023,
#     -0.00365953,
#     21.375286,
#     21.35802469,
#     17.40740741,
#     -0.0022065,
#     -0.00294608]},
#   {'s': 'LSE:RENE',
#    'd': ['RENEURON GROUP ORD GBP0.01',
#     0.09090909,
#     27.6315031,
#     -0.05,
#     -0.460085,
#     -26.29576846,
#     44.44444444,
#     45.56176848,
#     -0.35326477,
#     -0.41824732]},
#   {'s': 'LSE:CAD',
#    'd': ['CADOGAN ENERGY SOLUTIONS PLC ORD GBP0.03',
#     0.09090909,
#     24.1924258,
#     0.05,
#     -0.21120735,
#     -40.03955604,
#     39.64476634,
#     38.68674676,
#     -0.10317417,
#     -0.11056615]},
#   {'s': 'LSE:URAH',
#    'd': ['URA HOLDINGS PLC ORD GBP0.0001',
#     -0.09090909,
#     44.46172263,
#     0.15,
#     0.05283235,
#     34.37479182,
#     70,
#     78.08769513,
#     -0.0321622,
#     -0.06627335]},
#   {'s': 'LSE:PALM',
#    'd': ['PANTHER METALS PLC ORD NPV',
#     -0.09090909,
#     41.30166351,
#     -0.1,
#     -0.08537059,
#     -103.67207515,
#     30.55555556,
#     37.96296296,
#     -0.01330863,
#     -0.00239752]},
#   {'s': 'LSE:MILA',
#    'd': ['MILA RESOURCES PLC ORD GBP0.01',
#     -0.18181818,
#     48.11165581,
#     0.041,
#     -0.02022706,
#     129.7276065,
#     88.289791,
#     82.92606064,
#     -0.01757342,
#     -0.02893502]},
#   {'s': 'LSE:SCIR',
#    'd': ['SCIROCCO ENERGY PLC ORD GBP0.002',
#     0.09090909,
#     31.78587484,
#     -0.074,
#     -0.06207741,
#     -130.31830666,
#     16.29593014,
#     16.49129304,
#     -0.02320827,
#     -0.01823591]},
#   {'s': 'LSE:TUN',
#    'd': ['TUNGSTEN WEST PLC ORD GBP0.01',
#     0.09090909,
#     20.94098484,
#     -0.05,
#     -0.10661176,
#     -154.78040329,
#     38.88888889,
#     42.59259259,
#     -0.13286728,
#     -0.17016384]},
#   {'s': 'LSE:SRES',
#    'd': ['SUNRISE RESOURCES ORD GBP0.001',
#     -0.09090909,
#     30.36320117,
#     -0.003,
#     -0.00244706,
#     -117.04359991,
#     17.69230769,
#     21.4957265,
#     -0.00207639,
#     -0.00257092]},
#   {'s': 'LSE:RUA',
#    'd': ['RUA LIFE SCIENCES PLC ORD GBP0.05',
#     0,
#     34.54772249,
#     -1.75,
#     -2.35146912,
#     -62.51111,
#     27.61904762,
#     28.25396825,
#     -1.03599925,
#     -0.974728]},
#   {'s': 'LSE:DEMG',
#    'd': ['DELTEX MEDICAL GROUP ORD GBP0.0001',
#     0,
#     9.76482304,
#     -0.0159,
#     -0.01183265,
#     -197.44631633,
#     48.5,
#     55.05555556,
#     -0.01061165,
#     -0.01259781]},
#   {'s': 'LSE:TRP',
#    'd': ['TOWER RESOURCES ORD GBP0.00001',
#     0,
#     41.15190395,
#     -0.001,
#     -0.00235574,
#     -39.185055,
#     35.48387097,
#     37.27598566,
#     -0.00111516,
#     -0.00125771]},
#   {'s': 'LSE:DIS',
#    'd': ['DISTIL PLC ORD GBP0.001',
#     0.18181818,
#     2.38678757,
#     -0.025,
#     -0.03322059,
#     -4.99102737,
#     54.16666667,
#     47.06790123,
#     -0.01997236,
#     -0.02112106]},
#   {'s': 'LSE:LDSG',
#    'd': ['LEEDS GROUP ORD GBP0.12',
#     0,
#     18.9884001,
#     -0.5,
#     -1.96970588,
#     -67.60591427,
#     18.01801802,
#     17.51659917,
#     -0.68529439,
#     -0.46793066]},
#   {'s': 'LSE:REE',
#    'd': ['ALTONA RARE EARTHS PLC ORD GBP0.01',
#     0,
#     15.6511354,
#     -0.375,
#     -0.28045485,
#     -207.95023498,
#     4.16666667,
#     8.7962963,
#     -0.17772416,
#     -0.15779366]},
#   {'s': 'LSE:WTE',
#    'd': ['WESTMOUNT ENERGY ORD NPV',
#     -0.09090909,
#     32.32827734,
#     -0.05,
#     -0.07662941,
#     -133.22277501,
#     25,
#     33.33333333,
#     -0.02809541,
#     -0.02675404]},
#   {'s': 'LSE:GFIN',
#    'd': ['GFINITY PLC ORD GBP0.0001',
#     0,
#     46.05860065,
#     0.0015,
#     -0.00285735,
#     -17.11362876,
#     21.71717172,
#     24.57912458,
#     -0.00252966,
#     -0.00364808]},
#   {'s': 'LSE:TOM',
#    'd': ['TOMCO ENERGY PLC ORD NPV',
#     -0.09090909,
#     68.09744175,
#     0.0122,
#     0.01430985,
#     73.09169635,
#     80,
#     77.98245614,
#     0.00501461,
#     0.00377877]},
#   {'s': 'LSE:EST',
#    'd': ['EAST STAR RESOURCES PLC ORD GBP0.01',
#     -0.09090909,
#     15.84628787,
#     -0.217,
#     -0.19734118,
#     -190.69550208,
#     27.75326076,
#     33.44183927,
#     -0.1043517,
#     -0.10966794]},
#   {'s': 'LSE:TYM',
#    'd': ['TERTIARY MINERALS ORD GBP0.0001',
#     -0.18181818,
#     37.24385485,
#     -0.0198,
#     -0.01359941,
#     -157.60777541,
#     22.46319172,
#     26.26129769,
#     -0.00142769,
#     0.00191082]},
#   {'s': 'LSE:DSG',
#    'd': ['DILLISTONE GROUP ORD GBP0.05',
#     0.11111111,
#     25.15457943,
#     0,
#     -0.39212794,
#     -38.01502306,
#     100,
#     91.00533384,
#     -0.22607248,
#     -0.26080072]},
#   ...],
#  'params': {'uk': {'symbols': {'query': {'types': ['stock', 'fund', 'dr']}},
#    'filter': [{'left': 'is_primary', 'operation': 'equal', 'right': True},
#     {'left': 'typespecs', 'operation': 'has', 'right': 'common'},
#     {'left': 'typespecs', 'operation': 'has_none_of', 'right': 'cdi'},
#     {'left': 'type', 'operation': 'equal', 'right': 'stock'}],
#    'sort': {'sortBy': 'market_cap_basic',
#     'sortOrder': 'desc',
#     'nullsFirst': False},
#    'options': {'lang': 'en'}}}}

# %%
def craftColumns(myDict, payloadJSON):
    
    """
    myDict: A hardcoded dicitionary that holds payload values and their corresponding manifistation on the page 
    myJSON: a json of the values sent in the payload
    Returns: A list of the column names pulled from the page itself as opposed to keys used to address the API
    """
    
    pageVals = []
    myColumns = payloadJSON['columns']
    
    for row in myColumns:
        
        if row in myDict.values():

            for key,val in myDict.items():
                

                if val == row:
                    pageVals.append(key)

        else:
            pageVals.append(row)

    return pageVals

# %%
resp = getCountryTable(basePath + 'jsonFiles\\ActualFiles\\canadaValuationPayload.json','canada')

# %%
def createCsv(fileName, country, response, valuesDict, payloadJSON):
    """
    Response: sever's response (JSON)
    fileName: Name of file you'll be creating to write the result to
    Columns: A list that will be written to the first row of the csv
    
    """
    
    columns = craftColumns(valuesDict, payloadJSON)
    if country not in os.listdir(basePath + 'csvs\\'):
        os.mkdir(basePath + 'csvs\\{}'.format(country))

    with open(basePath + 'csvs\\{}\\{}.csv'.format(country, fileName), 'w', newline='') as file:

        
        serverResp = response['data']
        writer = csv.writer(file)
        writer.writerow(columns)

        for i in range(len(serverResp)):

            writer.writerow(serverResp[i]['d'])

# %%
createCsv('smth', 'canada', resp, valuation, json.loads(open(basePath + 'jsonFiles\\ActualFiles\\canadaValuationPayload.json').read()))

# %%
res = getCountryTable(basePath + "jsonFiles\\ActualFiles\\canadaOscillatorsPayload.json", 'nigeria', reqRows = 30000)

# %%
def countryAllCSVS(payloadsPath, country):
    
    tables = []
    tablesCap = []
    payloads = os.listdir(payloadsPath)
    
    
    for payload in payloads:
        tableName = extractCatName('canada',payload)
        tablesCap.append(tableName)
        tables.append(tableName.lower())
    
    
    for table in tables:

        for dic in dictsList:
            
            if dic['title'] == table:
                
                #print("{} == {}".format(dic['title'],table))
                payloadString = basePath + "jsonFiles\\ActualFiles\\canada{}Payload.json".format(tablesCap[tables.index(table)])
                resp = getCountryTable((payloadString), country, reqRows = 20000)
                createCsv(country+table.capitalize(), country[1], resp, dic, json.loads(open(basePath + 'jsonFiles\\ActualFiles\\canada{}Payload.json'.format(tablesCap[tables.index(table)])).read()))
   
    
countryAllCSVS(basePath + 'jsonFiles\\ActualFiles\\', 'egypt')

# %%
def getAllTablesAllCountries(payloadsPath):
    
    
    """
    DESCRIPTION: This function loops over all the tables for all countries and saves them into csvs in a specified folder 
    """
    
    failed_list = []
    i = 0
    countries =  countryLinksFromPage('https://www.tradingview.com/markets/stocks-usa/market-movers-large-cap/')
    print("There are {} countries\n", format(len(countries)))
    for country in countries:
        i += 1
        print("Doing country number {}".format(i))
        try:
            print("Trying to grab the csvs for {}".format(country[1]))
            countryAllCSVS(payloadsPath, country[1])
            print("SUCCESS\n\n\n")
            time.sleep(1)


        except:
            
            try:
            
                if country[1] == 'usa':
                    countryAllCSVS(payloadsPath, 'america')

                elif country[1] == 'united-kingdom':
                    countryAllCSVS(payloadsPath, 'uk')
                    
                elif country[1] == 'south-africa':
                    countryAllCSVS(payloadsPath, 'rsa')

                elif '-' in country[1]:
                    countryAllCSVS(payloadsPath, country[1].replace('-',''))
                    
                



                    print("WE FAILED")
                    print("The country we failed was: ", country[1])
                    print("\n\n\n")
                    
            except:
                failed_list.append(country)
                
    return failed_list
